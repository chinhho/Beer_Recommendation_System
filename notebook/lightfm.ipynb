# %%
import pandas as pd
import numpy as np
import scipy
from lightfm.data import Dataset
from lightfm import LightFM
#this line for fix an interantions between train and test
LightFM._check_test_train_intersections = lambda x, y, z: True
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
# Out:
# /Users/hochinh/opt/anaconda3/lib/python3.7/site-packages/lightfm/_lightfm_fast.py:10: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   "LightFM was compiled without OpenMP support. "

# %%
df=pd.read_csv('data.csv', index_col=[0])

# %%
df.head()
# Out:
#                Beers            Brewery   abv                      Url  \
# 0  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 1  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 2  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 3  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 4  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
#
#         Id         Rater                From  Rating  Id_beer
# 0  1311021  Derptiluderp        from Indiana    1.23        1
# 1   736885           DCH       from New York    3.99        1
# 2  1310518        md3kcn           from Ohio    2.46        1
# 3  1301271    RobertB412   from Pennsylvania    3.92        1
# 4  1309542   BarfyMan362        from Indiana    4.78        1

# %% [markdown]
# LightFM model gives implicit feedback, so I only took raters who voted >=3 and assumed that they like it.

# %%
df=df[df['Rating']>=3]

# %%
df.head()
# Out:
#                Beers            Brewery   abv                      Url  \
# 1  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 3  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 4  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 7  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
# 8  Traditional Lager  Yuengling Brewery  4.50  /beer/profile/182/1351/
#
#         Id        Rater                From  Rating  Id_beer
# 1   736885          DCH       from New York    3.99        1
# 3  1301271   RobertB412   from Pennsylvania    3.92        1
# 4  1309542  BarfyMan362        from Indiana    4.78        1
# 7    65915  jockstrappy   from Pennsylvania    3.03        1
# 8   188701    philbe311   from Pennsylvania    3.10        1

# %% [markdown]
# # Preparing dataset

# %% [markdown]
# Before to put data in model, LightFm requires its own dataset.

# %%
#creat data to fit in lightfm model
dataset = Dataset()
dataset.fit((x for x in df.Rater),
            (x for x in df.Beers),
           item_features=(x for x in df.abv),
           user_features=(x for x in df.From))

# %%
dataset.mapping()
# Out:
# ({'DCH': 0,
#   'RobertB412': 1,
#   'BarfyMan362': 2,
#   'jockstrappy': 3,
#   'philbe311': 4,
#   'Singlefinpin': 5,
#   'CindyFromOmaha': 6,
#   'ClinchMtnMan': 7,
#   'Skor304': 8,
#   'Dingbat88': 9,
#   'BobsyerUncle____Bob': 10,
#   'Sabtos': 11,
#   'jesthu': 12,
#   'marcablanc96': 13,
#   'Brook82': 14,
#   '1009': 15,
#   'izraelc': 16,
#   'jwp777': 17,
#   'realJohnnyHobo': 18,
#   'zuker21': 19,
#   'MrOH': 20,
#   'dingers': 21,
#   'Peach63': 22,
#   'nicholas2121': 23,
#   'shambeano': 24,
#   'thesherrybomber': 25,
#   'TooManyGlasses': 26,
#   'hk117': 27,
#   'sjrider': 28,
#   'misteil': 29,
#   'jjones12': 30,
#   'PorterPro125': 31,
#   'schoolboy': 32,
#   'wmscottsimpsonjr': 33,
#   'DypsoBubble': 34,
#   'BB1313': 35,
#   'Alexc11': 36,
#   'Gostlool': 37,
#   'crickrun': 38,
#   'moodenba': 39,
#   'ArchimedesSox': 40,
#   'md3kcn': 41,
#   'DrBeergood': 42,
#   'Mdog': 43,
#   'sjdevel': 44,
#   'Gaetan0': 45,
#   'DaveAhl': 46,
#   'Tantonys': 47,
#   'PMakowski': 48,
#   'SmokySignals': 49,
#   'Urtravel': 50,
#   'VoxRationis': 51,
#   'RonHen': 52,
#   'ChrisBeerDrinker94': 53,
#   'SAUbrewcrew': 54,
#   'spectru': 55,
#   'ML123': 56,
#   'crazyspicychef': 57,
#   'jmbrill81': 58,
#   'BJB13': 59,
#   'Vetbidder': 60,
#   'Tacoma223': 61,
#   'stevoj': 62,
#   'AccipiterofBeer': 63,
#   'mothmanscott': 64,
#   'DefenCorps': 65,
#   'Bouleboubier': 66,
#   'Beginner2': 67,
#   'Brutaltruth': 68,
#   'badgerbeer1': 69,
#   'Sprowt20': 70,
#   'depechemode1983': 71,
#   'Krajnyak': 72,
#   'gvickery': 73,
#   'chitoryu12': 74,
#   '57md': 75,
#   'BeerMan247': 76,
#   'OK_Denise': 77,
#   'defunksta': 78,
#   'dcscientist': 79,
#   'Trailboss76': 80,
#   'RyanK252': 81,
#   'Sgt_1991': 82,
#   'JimboBrews54': 83,
#   'German-Helles': 84,
#   'MacAuthur': 85,
#   'Hazy_fo_shazy': 86,
#   'KLHBB': 87,
#   'CTHomer': 88,
#   'dwmdrums': 89,
#   'Tilley4': 90,
#   'WoodBrew': 91,
#   'DavetotheB': 92,
#   'Darkmagus82': 93,
#   'jkblr': 94,
#   'MoreBeer4me': 95,
#   'Korbynlehr': 96,
#   'sokol_1993': 97,
#   'guynametyler': 98,
#   'BruceLombardo': 99,
#   'Jelitikasez': 100,
#   'Cthulhusquid': 101,
#   'connecticutpoet': 102,
#   'Schlitz74': 103,
#   'tblee12356': 104,
#   'stlfatguy': 105,
#   'BeerBobber': 106,
#   'Annstarrr': 107,
#   'AngusOg': 108,
#   'biboergosum': 109,
#   'Myotus': 110,
#   'Lahoi': 111,
#   'ralph-pine': 112,
#   'Gote': 113,
#   'jlindros': 114,
#   'REVZEB': 115,
#   'HoppingMadMonk': 116,
#   'michaelsmith11': 117,
#   'Czequershuus': 118,
#   'pianoguy': 119,
#   'ordybill': 120,
#   'mikeg67': 121,
#   'B-rett': 122,
#   'Zopiac': 123,
#   'scaliasux': 124,
#   'jimmah120': 125,
#   'agreenman19': 126,
#   'bwood06': 127,
#   'Stevedore': 128,
#   'Mitzvahman72': 129,
#   'vainosuomi': 130,
#   'rodbeermunch': 131,
#   'Barnoloid': 132,
#   'JohnnyLaw': 133,
#   'Evilyak': 134,
#   'nhindian': 135,
#   'q33jeff': 136,
#   'woodychandler': 137,
#   'superspak': 138,
#   'TtheGrey': 139,
#   '1000lbgrizzly': 140,
#   'microbrewlover': 141,
#   'NateDyk47': 142,
#   'Redrover': 143,
#   'LXIXME': 144,
#   'thecheapies': 145,
#   'DrinkSlurm': 146,
#   'Cyberkedi': 147,
#   'scootny': 148,
#   'bnes09': 149,
#   'sommersb': 150,
#   'bubseymour': 151,
#   'metter98': 152,
#   'SolipsismalCat': 153,
#   'wedge': 154,
#   'kylehay2004': 155,
#   'brentk56': 156,
#   'tastybeer': 157,
#   'BEERMILER12': 158,
#   'milkshakebeersucks': 159,
#   'Tony787': 160,
#   'AyatollahGold': 161,
#   'Larryfunnell': 162,
#   'eberesford': 163,
#   'Rasmonton': 164,
#   'GoBearsWalter34': 165,
#   'ewpass': 166,
#   'Hackattack': 167,
#   'reddfoot': 168,
#   'portwood': 169,
#   'TheManiacalOne': 170,
#   'BlackBeerPirate': 171,
#   'Noelan': 172,
#   'cosmin': 173,
#   'beersareonme': 174,
#   'Timothy_Scott_Goeft': 175,
#   'josanguapo': 176,
#   'dacrza1': 177,
#   'Stephenkerr': 178,
#   'beersampler6': 179,
#   'Chatterbox': 180,
#   'Glutard': 181,
#   'Melena99': 182,
#   'kimlhurst': 183,
#   'cms121': 184,
#   'Ncollins': 185,
#   'pat61': 186,
#   'entenduintransit': 187,
#   'Aegelis': 188,
#   'EmperorBatman': 189,
#   'GreggFWTX': 190,
#   'Dave__4': 191,
#   'johnnyd10vt': 192,
#   'KatyBeerGuy': 193,
#   'tone77': 194,
#   'CP950': 195,
#   'EMH73': 196,
#   'NastyNorseman': 197,
#   'iheartmyTHO': 198,
#   'Gajo74': 199,
#   'sprat1960': 200,
#   'TheSixthRing': 201,
#   'SteveB24': 202,
#   'UCLABrewN84': 203,
#   'CalgaryFMC': 204,
#   'stephens101': 205,
#   'Hdredfern': 206,
#   'archyquaffer': 207,
#   'JMad': 208,
#   'RonaldTheriot': 209,
#   'AlCaponeJunior': 210,
#   'M_C_Hampton': 211,
#   'u2carew': 212,
#   'MikeyA': 213,
#   'Suds': 214,
#   'cyclonece09': 215,
#   'mngermanshepherd': 216,
#   'SB2017': 217,
#   'detgfrsh': 218,
#   'cardfan212': 219,
#   'MonDak_Joe1953': 220,
#   'dav2080': 221,
#   'LooseGasCap': 222,
#   'jamphanatic': 223,
#   'cuttlery': 224,
#   'Squire': 225,
#   'Victory_Sabre1973': 226,
#   'AleMan66': 227,
#   'jdseltzer': 228,
#   'jwc215': 229,
#   'bluto1998': 230,
#   'Wer34truh': 231,
#   'dorlandenator': 232,
#   'CisPiece88': 233,
#   'Hopheadjeffery': 234,
#   'Creevo': 235,
#   'hoptheology': 236,
#   'Sam_Sorrells': 237,
#   'Vixie': 238,
#   'The-Beav': 239,
#   'BryanCarey': 240,
#   'Fcolle2': 241,
#   'guityler83': 242,
#   'siege06nd': 243,
#   'andrenaline': 244,
#   'ferrari29': 245,
#   'NilocRellim': 246,
#   'KickbacksSteve': 247,
#   'falloutsnow': 248,
#   'TX-Badger': 249,
#   'gchapman1081': 250,
#   'octortus': 251,
#   'argock': 252,
#   'dbl_delta': 253,
#   'Deca': 254,
#   'Svingjo': 255,
#   'johnnnniee': 256,
#   'vincehayter': 257,
#   'Bunman3': 258,
#   'kevofficiel': 259,
#   'patre_tim': 260,
#   'DrDemento456': 261,
#   'Pmicdee': 262,
#   'taxandbeerguy': 263,
#   'The-Jolly-Imbiber': 264,
#   'StonedTrippin': 265,
#   'kevinlater': 266,
#   'The_Befus': 267,
#   'Vyacheslav': 268,
#   'Mysticmage': 269,
#   'FriedSlug': 270,
#   'mdfb79': 271,
#   'MichaelGennings': 272,
#   'TheBigBeerGuy19': 273,
#   'Lagerlivesmatter': 274,
#   'Lewnanny': 275,
#   'VincentGR': 276,
#   'D-HopSupreme': 277,
#   'akdo': 278,
#   'N1120A': 279,
#   'Tsar_Riga': 280,
#   'Pskihq92': 281,
#   'beergoot': 282,
#   'hoppydanknessOG': 283,
#   'William295': 284,
#   'Buckeye55': 285,
#   'Bevitore': 286,
#   'Foyle': 287,
#   'Scottync': 288,
#   'Ltdsaint': 289,
#   'chinchill': 290,
#   'briandschorr': 291,
#   'tjwarren': 292,
#   'Guppy314': 293,
#   'Brian_L-2056': 294,
#   'ljdrinksbeer': 295,
#   'Immortale25': 296,
#   'TheRougeBastard': 297,
#   'Chill12892': 298,
#   'SFNC': 299,
#   'notascoolasyou': 300,
#   'wahootodd': 301,
#   'zshaft': 302,
#   'oberon': 303,
#   'jneiswender': 304,
#   'StoutElk_92': 305,
#   'ScaryEd': 306,
#   'Sheppard': 307,
#   'scotorum': 308,
#   'nodder': 309,
#   'h4ger': 310,
#   'Theheroguy': 311,
#   'Beric': 312,
#   'HBBJ': 313,
#   'irrevjim': 314,
#   'GuitarIPA': 315,
#   'puboflyons': 316,
#   'fscottkey': 317,
#   'Chris_Carraher': 318,
#   'mterrence5': 319,
#   'WunderLlama': 320,
#   'Flounder57': 321,
#   'jeffdr123': 322,
#   'KilleenTx': 323,
#   'puck1225': 324,
#   'Jbbdrinker': 325,
#   'arizcards': 326,
#   'wejohnsn': 327,
#   'infinitebruner': 328,
#   'sgt_187em': 329,
#   'Penrodeo': 330,
#   'KTCamm': 331,
#   'ZBowden': 332,
#   'ssteakley': 333,
#   'a0lbudman': 334,
#   'Premo88': 335,
#   'Boto': 336,
#   'mjurney': 337,
#   'AdmiralOzone': 338,
#   'drpimento': 339,
#   'BigDaddyWarbuxx': 340,
#   'Pegasus': 341,
#   'Cylinsier': 342,
#   'StoutHunter': 343,
#   'vette2006c5r': 344,
#   'BrewAskew': 345,
#   'jazzyjeff13': 346,
#   'EmperorBevis': 347,
#   'Hergestridge': 348,
#   'TheSSG': 349,
#   'BlackHaddock': 350,
#   'TheBierdimpfe': 351,
#   'CanadianAviator': 352,
#   'DaveBar': 353,
#   'papat444': 354,
#   'souvenirs': 355,
#   'Mountainmanbrewing': 356,
#   'Olek4374': 357,
#   'AlexDuMond': 358,
#   'Slatetank': 359,
#   'bacabuck': 360,
#   'BCJoly': 361,
#   'BostonHops': 362,
#   'greenhousedrummer': 363,
#   'stortore': 364,
#   'BSiegs': 365,
#   'Ri0': 366,
#   'Tone': 367,
#   'NickSMpls': 368,
#   'Alan_Bats': 369,
#   'SanWrencho': 370,
#   'mfnmbvp': 371,
#   'rlee1390': 372,
#   'zeledonia': 373,
#   'Beerandraiderfan': 374,
#   'Mindcrime1000': 375,
#   'marcobrau': 376,
#   'FBarber': 377,
#   'AndrewMichael': 378,
#   'MUTINY': 379,
#   'obywan59': 380,
#   'delta490': 381,
#   'Dodo2step': 382,
#   'Mikecap': 383,
#   'bluedognever': 384,
#   'hmich176': 385,
#   'beerthulhu': 386,
#   'Minkybut': 387,
#   'oriolesfan4': 388,
#   'Crazyale': 389,
#   'ralree': 390,
#   'KMcG': 391,
#   'ackleydg': 392,
#   'jadpsu': 393,
#   'Martin194': 394,
#   'Dandabard': 395,
#   'G2Brew': 396,
#   'wallaceandvomit': 397,
#   'matty': 398,
#   'tjsdomer2': 399,
#   'Mora2000': 400,
#   'greywolf': 401,
#   'katan': 402,
#   'kegger22': 403,
#   'BlurryVisi0n': 404,
#   'Kromes': 405,
#   'JerseyKirk': 406,
#   'Luigi': 407,
#   'tigg924': 408,
#   'rel': 409,
#   'Arithmeticus': 410,
#   'jsprain1': 411,
#   'Bluecrow': 412,
#   'Scotchboy': 413,
#   'johannyne': 414,
#   'malinali14': 415,
#   'JLaw55': 416,
#   'Mark-Leggett': 417,
#   'Holderness': 418,
#   'mothman': 419,
#   'rickyfinn': 420,
#   'ZAP': 421,
#   'Zhoxush': 422,
#   'Kayakguy': 423,
#   'brewale4me': 424,
#   'mvanaskie13': 425,
#   'mlockman': 426,
#   'NeroFiddled': 427,
#   'DavoleBomb': 428,
#   'MarkQ617': 429,
#   'HardTarget': 430,
#   'Caveworm': 431,
#   'Fitzy01': 432,
#   'PatrickCT': 433,
#   '4liter': 434,
#   'kevin3046': 435,
#   'DrMullet': 436,
#   'NextBestThing': 437,
#   'generallee': 438,
#   'Lettice123': 439,
#   'singletary': 440,
#   'jjamadorphd': 441,
#   'Scott17Taylor': 442,
#   'BeerAndGasMasks': 443,
#   'BrownAleBollocks': 444,
#   'BeerWithMike': 445,
#   'NiceTaps': 446,
#   'TheBrewo': 447,
#   'TheCondor': 448,
#   'CraftyHusker': 449,
#   'rangerred': 450,
#   'Gavage': 451,
#   'AgentMunky': 452,
#   'searsclone': 453,
#   'jmbranum': 454,
#   'Charliethebrit': 455,
#   'dcotom': 456,
#   'ReviewInABag': 457,
#   'goodsuds': 458,
#   'dueserdo': 459,
#   'Burly': 460,
#   'OldSwampy': 461,
#   'the_awesometeer': 462,
#   'BEERchitect': 463,
#   'Spikester': 464,
#   'Billolick': 465,
#   'PhilHeinricke': 466,
#   'transitionbikes93': 467,
#   'CIBoy10': 468,
#   'gandres': 469,
#   'Md35': 470,
#   'SamuelMiller': 471,
#   'Libeertarian': 472,
#   'RJLarse': 473,
#   'dbrauneis': 474,
#   'Redneckwine': 475,
#   'zander4dawin': 476,
#   'Act25': 477,
#   'ryan1788a5': 478,
#   'Zorro': 479,
#   'TheRealBigC': 480,
#   'vkv822': 481,
#   'Bockrules': 482,
#   'Gr8-Nate': 483,
#   'TheMarkE': 484,
#   'Jugs_McGhee': 485,
#   'Fatehunter': 486,
#   'wac9': 487,
#   'Kendo': 488,
#   'Hoptometrist': 489,
#   'MadScientist': 490,
#   'twiggamortis420': 491,
#   'Brenden': 492,
#   'RblWthACoz': 493,
#   'zeff80': 494,
#   'barczar': 495,
#   'Jocose47': 496,
#   'harpo111': 497,
#   'tuathaunderhill': 498,
#   'NorthernMichiganLogan': 499,
#   'KentT': 500,
#   'Ob512316': 501,
#   'OldSchoolMike': 502,
#   'TBDave': 503,
#   'Troy-Hawaii': 504,
#   'Bito24': 505,
#   'Misanthropy_Sipping': 506,
#   'Prager62': 507,
#   'buschbeer': 508,
#   'donspublic': 509,
#   'RockySasquatch': 510,
#   'chlsmith': 511,
#   'Retroman40': 512,
#   'car2052': 513,
#   'KYGunner': 514,
#   'Schwarzwald': 515,
#   'yumyumbrew': 516,
#   'screamking': 517,
#   'GossageBrewery': 518,
#   'patpbr': 519,
#   'baos': 520,
#   'somaohio': 521,
#   'keeganfrank': 522,
#   'CAMRAhardliner': 523,
#   'Tripel_Threat': 524,
#   'rhoadsrage': 525,
#   'TreyIsWilson': 526,
#   'SerialTicker': 527,
#   'maximum12': 528,
#   'Huhzubendah': 529,
#   'andrewjraab': 530,
#   'tectactoe': 531,
#   'BeastOfTheNortheast': 532,
#   'Wattie83': 533,
#   'smcolw': 534,
#   'GreesyFizeek': 535,
#   'Tucquan': 536,
#   'Lingenbrau': 537,
#   'ClePaul': 538,
#   'Scrapss': 539,
#   'BeerBatteredPhish': 540,
#   'Uniobrew31': 541,
#   'Sipchue': 542,
#   'nukem5': 543,
#   'Mister_Falcon': 544,
#   'jifigz': 545,
#   'paulhargus': 546,
#   'jmdrpi': 547,
#   'GStone899': 548,
#   'Nosquatch': 549,
#   'Baumer': 550,
#   'atniup': 551,
#   '88caprice': 552,
#   'lwillitz': 553,
#   'carlborch': 554,
#   'GRPunk': 555,
#   'FanofHefe': 556,
#   'kbeals': 557,
#   'bozebus17': 558,
#   'mjohn27603': 559,
#   'LampertLand': 560,
#   'Phyl21ca': 561,
#   'decimator': 562,
#   'wordemupg': 563,
#   'CrazyMike': 564,
#   'xuptygm': 565,
#   'atigerlife': 566,
#   'berley31': 567,
#   'biegaman': 568,
#   'terryeckmeier': 569,
#   'MisterClean': 570,
#   '1759Girl': 571,
#   'BDTyre': 572,
#   'humuloner22': 573,
#   'blackie': 574,
#   'brewdude1982': 575,
#   'cosmicevan': 576,
#   'kneeland': 577,
#   'tdm168': 578,
#   'smellandsip37': 579,
#   'jsanford': 580,
#   'Onenote81': 581,
#   'wcudwight': 582,
#   'BieresDesMoines': 583,
#   'Jason': 584,
#   'ChainGangGuy': 585,
#   'elNopalero': 586,
#   'BucannonXC5': 587,
#   'maddogruss': 588,
#   'Rick5150': 589,
#   'Cavanaghty': 590,
#   'justintcoons': 591,
#   'SawDog505': 592,
#   'chrishiker1409': 593,
#   'Chickenhawk9932': 594,
#   'wattoclone': 595,
#   'raizin': 596,
#   'LF_Evan': 597,
#   'HorseheadsHophead': 598,
#   'utopiajane': 599,
#   'tempest': 600,
#   'DoubleMalt': 601,
#   'ajm5108': 602,
#   'jzeilinger': 603,
#   'crisis1290': 604,
#   'kgammell1': 605,
#   'MisledTitan': 606,
#   'bobfinkenaur': 607,
#   'Samp01': 608,
#   'jhartley': 609,
#   'jzlyo': 610,
#   'Extrajoker00': 611,
#   'StaveHooks': 612,
#   'Hopswagger': 613,
#   'JuicesFlowing': 614,
#   'kdawg105': 615,
#   'keethrax': 616,
#   'JRed': 617,
#   'sixtysixpixistix': 618,
#   'Nerudamann': 619,
#   'thegodfather1076': 620,
#   'sixerofelixir': 621,
#   'yesyouam': 622,
#   'Meisterlol': 623,
#   'TheWhiskerReview': 624,
#   'Franz4': 625,
#   'sethmeister': 626,
#   'Manta200': 627,
#   'Siriusfisherman': 628,
#   'Brad007': 629,
#   'hopsputin': 630,
#   'SmashAdams': 631,
#   'Jwale73': 632,
#   'MacMalt': 633,
#   'LeRose': 634,
#   'Parmesan': 635,
#   'Todd': 636,
#   'Mugman8': 637,
#   'Amendm': 638,
#   'sulldaddy': 639,
#   'KRug': 640,
#   'yuriyt': 641,
#   'farrago': 642,
#   'atr2605': 643,
#   'DFMCapeCod': 644,
#   'mikesgroove': 645,
#   'Rifugium': 646,
#   'coalcracker': 647,
#   'Buggies': 648,
#   'BuxMontBeerLover': 649,
#   'Clydesdale': 650,
#   'Reidrover': 651,
#   'WesWes': 652,
#   'hdofu': 653,
#   'Durge': 654,
#   'mralphabet': 655,
#   'Jamesk55': 656,
#   'BretSikkink': 657,
#   'treque': 658,
#   'allengarvin': 659,
#   'gpogo': 660,
#   'Kaitekiyoukai': 661,
#   'Yuuki': 662,
#   'crob3888': 663,
#   'maxifunk777': 664,
#   'Hop_God': 665,
#   'Rollzroyce21': 666,
#   'ZakFaruki': 667,
#   'Dainslaif': 668,
#   'Furlinator': 669,
#   'DoubleJ': 670,
#   'mactrail': 671,
#   'Jamesthebrit': 672,
#   'TrappistJohnMD': 673,
#   'projectflam86': 674,
#   'curasowa': 675,
#   'TheDeuce': 676,
#   'Avagadro': 677,
#   'majesticsock': 678,
#   'doctchad': 679,
#   'MTNboy': 680,
#   'wiseguy142': 681,
#   'animal69': 682,
#   'Bitterbill': 683,
#   'MountianBrews': 684,
#   'Impetuous': 685,
#   'willsail4beer': 686,
#   'dwarvenfriend': 687,
#   'chumba526': 688,
#   'einmt33': 689,
#   'JohnGalt1': 690,
#   'nghab': 691,
#   'RedChrome': 692,
#   'froghop': 693,
#   'therica': 694,
#   'kgotcher': 695,
#   'BigBry': 696,
#   'loren01': 697,
#   'ElGordo': 698,
#   'charlesw': 699,
#   'SkeeterHawk': 700,
#   'kbub6f': 701,
#   'GClarkage': 702,
#   'daliandragon': 703,
#   'willic': 704,
#   'GarthDanielson': 705,
#   'Apellonious': 706,
#   'jcbogantes': 707,
#   'marley2112': 708,
#   'SiriusBock': 709,
#   'rinhaak': 710,
#   'cagocubs': 711,
#   'tapman': 712,
#   'mpcrump': 713,
#   'secondtooth': 714,
#   'Sweetmambyjamby': 715,
#   'TheViolator666': 716,
#   'cameraready': 717,
#   'Wasatch': 718,
#   'tmitch75': 719,
#   'JamesS': 720,
#   'brewdlyhooked13': 721,
#   'MuenchenerKindl': 722,
#   'blitheringidiot': 723,
#   'BitteBier': 724,
#   'shbobdb': 725,
#   'karst': 726,
#   'richkrull': 727,
#   'Morey': 728,
#   'bgildea': 729,
#   'cdkrenz': 730,
#   'mikereaser': 731,
#   'tjd112': 732,
#   'MadTown1000': 733,
#   'asabreed': 734,
#   'mwa423': 735,
#   'hustlesworth': 736,
#   'BitterPachyderm': 737,
#   'ruckus232': 738,
#   'porterwoobie': 739,
#   'Pauly2X': 740,
#   'bsend': 741,
#   'ATLbeerDog': 742,
#   'Shumista': 743,
#   'Seanibus': 744,
#   'tedsox31': 745,
#   'seedyone': 746,
#   'DiabolikDUB': 747,
#   'Floydster': 748,
#   'SurlyDuff': 749,
#   'ClockworkOrange': 750,
#   'illidurit': 751,
#   'Deuane': 752,
#   'yourefragile': 753,
#   'Offa': 754,
#   'TheLongBeachBum': 755,
#   'EMV': 756,
#   'Smakawhat': 757,
#   'JohnCap523': 758,
#   'IronLover': 759,
#   'drtth': 760,
#   'larryi86': 761,
#   'jancona': 762,
#   'Joecaddie': 763,
#   'Mindsquall': 764,
#   'SebD': 765,
#   'Digimaika2': 766,
#   'spinrsx': 767,
#   'thehyperduck': 768,
#   'bylerteck': 769,
#   'bryehn': 770,
#   'liamt07': 771,
#   'TheHammer': 772,
#   'karait95': 773,
#   'allergictomacros': 774,
#   'Sammy': 775,
#   'EatsTacos': 776,
#   'GodOfBeer': 777,
#   'Derek': 778,
#   'Ironhand24680': 779,
#   'BeersNBars': 780,
#   'ChrisCage': 781,
#   'BuckyBeerBeaver': 782,
#   'Watershed': 783,
#   'JohnnyBarman': 784,
#   'JOaikido': 785,
#   'korguy123': 786,
#   'hopsolutely': 787,
#   'cratez': 788,
#   'heebes': 789,
#   'pootz': 790,
#   'madtappers': 791,
#   'bluemoonswoon': 792,
#   'prosper': 793,
#   'dnichols': 794,
#   'riversider76': 795,
#   'Bookseeb': 796,
#   'woemad': 797,
#   'Noxious26': 798,
#   'BigRedN': 799,
#   'brureview': 800,
#   'lic217': 801,
#   'dd43': 802,
#   'beerturf': 803,
#   'WhiteHillsStore': 804,
#   'BranfordBound': 805,
#   'Robwvu304': 806,
#   'Zonk': 807,
#   'dar482': 808,
#   'Treebs': 809,
#   'emerge077': 810,
#   'KDawg': 811,
#   'GbVDave': 812,
#   'aerozeppl': 813,
#   'jrallen34': 814,
#   'MasterSki': 815,
#   'Bubba83': 816,
#   'Kegatron': 817,
#   'diabecktic': 818,
#   'Arbitrator': 819,
#   'trbergman': 820,
#   'scruffwhor': 821,
#   'samie85': 822,
#   'Florida9': 823,
#   'MrMcGibblets': 824,
#   'wspscott': 825,
#   'nickynick': 826,
#   'JoshuaJ': 827,
#   'mday': 828,
#   'infideltaco': 829,
#   'malcontent': 830,
#   'mick303': 831,
#   'mintjellie': 832,
#   'Bobdope': 833,
#   'Brent': 834,
#   'drinkininthewood': 835,
#   'Mandrake': 836,
#   'IronDjinn': 837,
#   'kazaxson': 838,
#   'donmonkey1': 839,
#   'jettjon': 840,
#   'DarrellK': 841,
#   'budgood1': 842,
#   'mntlover': 843,
#   'breardon1776': 844,
#   'DocRoc': 845,
#   'Vestlake': 846,
#   'richj1970': 847,
#   'STKPICR0720': 848,
#   'pkalix': 849,
#   'BBThunderbolt': 850,
#   'Briken': 851,
#   'DirtyPenny': 852,
#   'nebula1999': 853,
#   'BMac17': 854,
#   'Halcyondays': 855,
#   'Gmann': 856,
#   'jaialainut': 857,
#   'DaveHS': 858,
#   'stakem': 859,
#   'letsgopens': 860,
#   'goldold': 861,
#   'treehugger02010': 862,
#   'shirfan': 863,
#   'Tallboy': 864,
#   'outdoorbrewer': 865,
#   'barrettds': 866,
#   'mentor': 867,
#   'Ricochet': 868,
#   'rabidawg': 869,
#   'GreatPondBrewer': 870,
#   'RaulMondesi': 871,
#   'ricke49': 872,
#   'boralyl': 873,
#   'PaulStoneAnchor': 874,
#   'NWer': 875,
#   'oregonskibum': 876,
#   'dukew456': 877,
#   'RedDiamond': 878,
#   'z_21': 879,
#   'hman43': 880,
#   'JeffreyPaulBradt': 881,
#   'barknee': 882,
#   'CNoj012': 883,
#   'gatornation': 884,
#   'jpro': 885,
#   'RyanDe680': 886,
#   'wolandjr': 887,
#   'MEPBlue': 888,
#   'Spaghett': 889,
#   'ngeunit1': 890,
#   'SFGuy187': 891,
#   'lechroy': 892,
#   'berkey': 893,
#   'augustgarage': 894,
#   'mjl21': 895,
#   'nickd717': 896,
#   'popery': 897,
#   'willjschmidt': 898,
#   'DIYMonkey': 899,
#   'Agriverbear': 900,
#   'ilikebeer03': 901,
#   'dhannes': 902,
#   'TMoney2591': 903,
#   'CaptainIPA': 904,
#   'objectivemonkey': 905,
#   'mynie': 906,
#   'svraines': 907,
#   'BeerBelcher': 908,
#   'circuitmonkey': 909,
#   'brewQ': 910,
#   'cokes': 911,
#   'BigGold': 912,
#   'fjrobinson44': 913,
#   'Jacurdy60': 914,
#   'lighthabit': 915,
#   'TheFlern': 916,
#   'suspect': 917,
#   'BowserBrew': 918,
#   'philbertk': 919,
#   'BuckeyeNation': 920,
#   'TheBishop': 921,
#   'ppoitras': 922,
#   'djeucalyptus': 923,
#   'Slats': 924,
#   'jdhilt': 925,
#   'Hanhwaeaglesv2': 926,
#   'FLima': 927,
#   'magictacosinus': 928,
#   'eduardolinhalis': 929,
#   'Mellonius': 930,
#   'endovelico': 931,
#   'AlexLMS': 932,
#   'fx20736': 933,
#   'bushbeer75': 934,
#   'DannyDan': 935,
#   'Schmidts': 936,
#   'bullwinkle88': 937,
#   'Knapp85': 938,
#   'almychristopher': 939,
#   'drxandy': 940,
#   'tmoneyba': 941,
#   'joemcgrath27': 942,
#   'peensteen': 943,
#   'TheSevenDuffs': 944,
#   'mrmanning': 945,
#   'gboy515duo': 946,
#   'h00dak': 947,
#   'JMH_': 948,
#   'ommegangpbr': 949,
#   'Phatz': 950,
#   'BeerAdvocate': 951,
#   'mdaschaf': 952,
#   'barleywinefiend': 953,
#   'dirtylou': 954,
#   'TheGent': 955,
#   'garymuchow': 956,
#   'Ahypercube': 957,
#   'BPVandenbroek': 958,
#   'Organdrew': 959,
#   'TheDoctor': 960,
#   'Poljazz22': 961,
#   'CanadianBacon': 962,
#   'lgmol': 963,
#   'FrostBlast': 964,
#   '4ster': 965,
#   'Jake-northrup': 966,
#   'flaskman': 967,
#   'thebeers': 968,
#   'LennyOvies': 969,
#   'Pexkool': 970,
#   'nano': 971,
#   'Gusler': 972,
#   'russpowell': 973,
#   'tesguino': 974,
#   'Jredner': 975,
#   'Gueuzedude': 976,
#   'fido': 977,
#   'Pepeton': 978,
#   'Shebeckastan': 979,
#   'OWSLEY069': 980,
#   'Mounty4Life': 981,
#   'ONovoMexicano': 982,
#   'MattyG85': 983,
#   'barnzy78': 984,
#   'beerguy04': 985,
#   'handmuffin': 986,
#   'LilBeerDoctor': 987,
#   'swim': 988,
#   'DaveandMargo': 989,
#   'Drew_wilks81': 990,
#   'Bashlet': 991,
#   'Frozensoul327': 992,
#   'Svart': 993,
#   '5thOhio': 994,
#   'dgilks': 995,
#   'ADZA': 996,
#   'Scott29': 997,
#   'BDIMike': 998,
#   'BlackDog': 999,
#   ...},
#  {'DCH': 0,
#   'RobertB412': 1,
#   'BarfyMan362': 2,
#   'jockstrappy': 3,
#   'philbe311': 4,
#   'Singlefinpin': 5,
#   'CindyFromOmaha': 6,
#   'ClinchMtnMan': 7,
#   'Skor304': 8,
#   'Dingbat88': 9,
#   'BobsyerUncle____Bob': 10,
#   'Sabtos': 11,
#   'jesthu': 12,
#   'marcablanc96': 13,
#   'Brook82': 14,
#   '1009': 15,
#   'izraelc': 16,
#   'jwp777': 17,
#   'realJohnnyHobo': 18,
#   'zuker21': 19,
#   'MrOH': 20,
#   'dingers': 21,
#   'Peach63': 22,
#   'nicholas2121': 23,
#   'shambeano': 24,
#   'thesherrybomber': 25,
#   'TooManyGlasses': 26,
#   'hk117': 27,
#   'sjrider': 28,
#   'misteil': 29,
#   'jjones12': 30,
#   'PorterPro125': 31,
#   'schoolboy': 32,
#   'wmscottsimpsonjr': 33,
#   'DypsoBubble': 34,
#   'BB1313': 35,
#   'Alexc11': 36,
#   'Gostlool': 37,
#   'crickrun': 38,
#   'moodenba': 39,
#   'ArchimedesSox': 40,
#   'md3kcn': 41,
#   'DrBeergood': 42,
#   'Mdog': 43,
#   'sjdevel': 44,
#   'Gaetan0': 45,
#   'DaveAhl': 46,
#   'Tantonys': 47,
#   'PMakowski': 48,
#   'SmokySignals': 49,
#   'Urtravel': 50,
#   'VoxRationis': 51,
#   'RonHen': 52,
#   'ChrisBeerDrinker94': 53,
#   'SAUbrewcrew': 54,
#   'spectru': 55,
#   'ML123': 56,
#   'crazyspicychef': 57,
#   'jmbrill81': 58,
#   'BJB13': 59,
#   'Vetbidder': 60,
#   'Tacoma223': 61,
#   'stevoj': 62,
#   'AccipiterofBeer': 63,
#   'mothmanscott': 64,
#   'DefenCorps': 65,
#   'Bouleboubier': 66,
#   'Beginner2': 67,
#   'Brutaltruth': 68,
#   'badgerbeer1': 69,
#   'Sprowt20': 70,
#   'depechemode1983': 71,
#   'Krajnyak': 72,
#   'gvickery': 73,
#   'chitoryu12': 74,
#   '57md': 75,
#   'BeerMan247': 76,
#   'OK_Denise': 77,
#   'defunksta': 78,
#   'dcscientist': 79,
#   'Trailboss76': 80,
#   'RyanK252': 81,
#   'Sgt_1991': 82,
#   'JimboBrews54': 83,
#   'German-Helles': 84,
#   'MacAuthur': 85,
#   'Hazy_fo_shazy': 86,
#   'KLHBB': 87,
#   'CTHomer': 88,
#   'dwmdrums': 89,
#   'Tilley4': 90,
#   'WoodBrew': 91,
#   'DavetotheB': 92,
#   'Darkmagus82': 93,
#   'jkblr': 94,
#   'MoreBeer4me': 95,
#   'Korbynlehr': 96,
#   'sokol_1993': 97,
#   'guynametyler': 98,
#   'BruceLombardo': 99,
#   'Jelitikasez': 100,
#   'Cthulhusquid': 101,
#   'connecticutpoet': 102,
#   'Schlitz74': 103,
#   'tblee12356': 104,
#   'stlfatguy': 105,
#   'BeerBobber': 106,
#   'Annstarrr': 107,
#   'AngusOg': 108,
#   'biboergosum': 109,
#   'Myotus': 110,
#   'Lahoi': 111,
#   'ralph-pine': 112,
#   'Gote': 113,
#   'jlindros': 114,
#   'REVZEB': 115,
#   'HoppingMadMonk': 116,
#   'michaelsmith11': 117,
#   'Czequershuus': 118,
#   'pianoguy': 119,
#   'ordybill': 120,
#   'mikeg67': 121,
#   'B-rett': 122,
#   'Zopiac': 123,
#   'scaliasux': 124,
#   'jimmah120': 125,
#   'agreenman19': 126,
#   'bwood06': 127,
#   'Stevedore': 128,
#   'Mitzvahman72': 129,
#   'vainosuomi': 130,
#   'rodbeermunch': 131,
#   'Barnoloid': 132,
#   'JohnnyLaw': 133,
#   'Evilyak': 134,
#   'nhindian': 135,
#   'q33jeff': 136,
#   'woodychandler': 137,
#   'superspak': 138,
#   'TtheGrey': 139,
#   '1000lbgrizzly': 140,
#   'microbrewlover': 141,
#   'NateDyk47': 142,
#   'Redrover': 143,
#   'LXIXME': 144,
#   'thecheapies': 145,
#   'DrinkSlurm': 146,
#   'Cyberkedi': 147,
#   'scootny': 148,
#   'bnes09': 149,
#   'sommersb': 150,
#   'bubseymour': 151,
#   'metter98': 152,
#   'SolipsismalCat': 153,
#   'wedge': 154,
#   'kylehay2004': 155,
#   'brentk56': 156,
#   'tastybeer': 157,
#   'BEERMILER12': 158,
#   'milkshakebeersucks': 159,
#   'Tony787': 160,
#   'AyatollahGold': 161,
#   'Larryfunnell': 162,
#   'eberesford': 163,
#   'Rasmonton': 164,
#   'GoBearsWalter34': 165,
#   'ewpass': 166,
#   'Hackattack': 167,
#   'reddfoot': 168,
#   'portwood': 169,
#   'TheManiacalOne': 170,
#   'BlackBeerPirate': 171,
#   'Noelan': 172,
#   'cosmin': 173,
#   'beersareonme': 174,
#   'Timothy_Scott_Goeft': 175,
#   'josanguapo': 176,
#   'dacrza1': 177,
#   'Stephenkerr': 178,
#   'beersampler6': 179,
#   'Chatterbox': 180,
#   'Glutard': 181,
#   'Melena99': 182,
#   'kimlhurst': 183,
#   'cms121': 184,
#   'Ncollins': 185,
#   'pat61': 186,
#   'entenduintransit': 187,
#   'Aegelis': 188,
#   'EmperorBatman': 189,
#   'GreggFWTX': 190,
#   'Dave__4': 191,
#   'johnnyd10vt': 192,
#   'KatyBeerGuy': 193,
#   'tone77': 194,
#   'CP950': 195,
#   'EMH73': 196,
#   'NastyNorseman': 197,
#   'iheartmyTHO': 198,
#   'Gajo74': 199,
#   'sprat1960': 200,
#   'TheSixthRing': 201,
#   'SteveB24': 202,
#   'UCLABrewN84': 203,
#   'CalgaryFMC': 204,
#   'stephens101': 205,
#   'Hdredfern': 206,
#   'archyquaffer': 207,
#   'JMad': 208,
#   'RonaldTheriot': 209,
#   'AlCaponeJunior': 210,
#   'M_C_Hampton': 211,
#   'u2carew': 212,
#   'MikeyA': 213,
#   'Suds': 214,
#   'cyclonece09': 215,
#   'mngermanshepherd': 216,
#   'SB2017': 217,
#   'detgfrsh': 218,
#   'cardfan212': 219,
#   'MonDak_Joe1953': 220,
#   'dav2080': 221,
#   'LooseGasCap': 222,
#   'jamphanatic': 223,
#   'cuttlery': 224,
#   'Squire': 225,
#   'Victory_Sabre1973': 226,
#   'AleMan66': 227,
#   'jdseltzer': 228,
#   'jwc215': 229,
#   'bluto1998': 230,
#   'Wer34truh': 231,
#   'dorlandenator': 232,
#   'CisPiece88': 233,
#   'Hopheadjeffery': 234,
#   'Creevo': 235,
#   'hoptheology': 236,
#   'Sam_Sorrells': 237,
#   'Vixie': 238,
#   'The-Beav': 239,
#   'BryanCarey': 240,
#   'Fcolle2': 241,
#   'guityler83': 242,
#   'siege06nd': 243,
#   'andrenaline': 244,
#   'ferrari29': 245,
#   'NilocRellim': 246,
#   'KickbacksSteve': 247,
#   'falloutsnow': 248,
#   'TX-Badger': 249,
#   'gchapman1081': 250,
#   'octortus': 251,
#   'argock': 252,
#   'dbl_delta': 253,
#   'Deca': 254,
#   'Svingjo': 255,
#   'johnnnniee': 256,
#   'vincehayter': 257,
#   'Bunman3': 258,
#   'kevofficiel': 259,
#   'patre_tim': 260,
#   'DrDemento456': 261,
#   'Pmicdee': 262,
#   'taxandbeerguy': 263,
#   'The-Jolly-Imbiber': 264,
#   'StonedTrippin': 265,
#   'kevinlater': 266,
#   'The_Befus': 267,
#   'Vyacheslav': 268,
#   'Mysticmage': 269,
#   'FriedSlug': 270,
#   'mdfb79': 271,
#   'MichaelGennings': 272,
#   'TheBigBeerGuy19': 273,
#   'Lagerlivesmatter': 274,
#   'Lewnanny': 275,
#   'VincentGR': 276,
#   'D-HopSupreme': 277,
#   'akdo': 278,
#   'N1120A': 279,
#   'Tsar_Riga': 280,
#   'Pskihq92': 281,
#   'beergoot': 282,
#   'hoppydanknessOG': 283,
#   'William295': 284,
#   'Buckeye55': 285,
#   'Bevitore': 286,
#   'Foyle': 287,
#   'Scottync': 288,
#   'Ltdsaint': 289,
#   'chinchill': 290,
#   'briandschorr': 291,
#   'tjwarren': 292,
#   'Guppy314': 293,
#   'Brian_L-2056': 294,
#   'ljdrinksbeer': 295,
#   'Immortale25': 296,
#   'TheRougeBastard': 297,
#   'Chill12892': 298,
#   'SFNC': 299,
#   'notascoolasyou': 300,
#   'wahootodd': 301,
#   'zshaft': 302,
#   'oberon': 303,
#   'jneiswender': 304,
#   'StoutElk_92': 305,
#   'ScaryEd': 306,
#   'Sheppard': 307,
#   'scotorum': 308,
#   'nodder': 309,
#   'h4ger': 310,
#   'Theheroguy': 311,
#   'Beric': 312,
#   'HBBJ': 313,
#   'irrevjim': 314,
#   'GuitarIPA': 315,
#   'puboflyons': 316,
#   'fscottkey': 317,
#   'Chris_Carraher': 318,
#   'mterrence5': 319,
#   'WunderLlama': 320,
#   'Flounder57': 321,
#   'jeffdr123': 322,
#   'KilleenTx': 323,
#   'puck1225': 324,
#   'Jbbdrinker': 325,
#   'arizcards': 326,
#   'wejohnsn': 327,
#   'infinitebruner': 328,
#   'sgt_187em': 329,
#   'Penrodeo': 330,
#   'KTCamm': 331,
#   'ZBowden': 332,
#   'ssteakley': 333,
#   'a0lbudman': 334,
#   'Premo88': 335,
#   'Boto': 336,
#   'mjurney': 337,
#   'AdmiralOzone': 338,
#   'drpimento': 339,
#   'BigDaddyWarbuxx': 340,
#   'Pegasus': 341,
#   'Cylinsier': 342,
#   'StoutHunter': 343,
#   'vette2006c5r': 344,
#   'BrewAskew': 345,
#   'jazzyjeff13': 346,
#   'EmperorBevis': 347,
#   'Hergestridge': 348,
#   'TheSSG': 349,
#   'BlackHaddock': 350,
#   'TheBierdimpfe': 351,
#   'CanadianAviator': 352,
#   'DaveBar': 353,
#   'papat444': 354,
#   'souvenirs': 355,
#   'Mountainmanbrewing': 356,
#   'Olek4374': 357,
#   'AlexDuMond': 358,
#   'Slatetank': 359,
#   'bacabuck': 360,
#   'BCJoly': 361,
#   'BostonHops': 362,
#   'greenhousedrummer': 363,
#   'stortore': 364,
#   'BSiegs': 365,
#   'Ri0': 366,
#   'Tone': 367,
#   'NickSMpls': 368,
#   'Alan_Bats': 369,
#   'SanWrencho': 370,
#   'mfnmbvp': 371,
#   'rlee1390': 372,
#   'zeledonia': 373,
#   'Beerandraiderfan': 374,
#   'Mindcrime1000': 375,
#   'marcobrau': 376,
#   'FBarber': 377,
#   'AndrewMichael': 378,
#   'MUTINY': 379,
#   'obywan59': 380,
#   'delta490': 381,
#   'Dodo2step': 382,
#   'Mikecap': 383,
#   'bluedognever': 384,
#   'hmich176': 385,
#   'beerthulhu': 386,
#   'Minkybut': 387,
#   'oriolesfan4': 388,
#   'Crazyale': 389,
#   'ralree': 390,
#   'KMcG': 391,
#   'ackleydg': 392,
#   'jadpsu': 393,
#   'Martin194': 394,
#   'Dandabard': 395,
#   'G2Brew': 396,
#   'wallaceandvomit': 397,
#   'matty': 398,
#   'tjsdomer2': 399,
#   'Mora2000': 400,
#   'greywolf': 401,
#   'katan': 402,
#   'kegger22': 403,
#   'BlurryVisi0n': 404,
#   'Kromes': 405,
#   'JerseyKirk': 406,
#   'Luigi': 407,
#   'tigg924': 408,
#   'rel': 409,
#   'Arithmeticus': 410,
#   'jsprain1': 411,
#   'Bluecrow': 412,
#   'Scotchboy': 413,
#   'johannyne': 414,
#   'malinali14': 415,
#   'JLaw55': 416,
#   'Mark-Leggett': 417,
#   'Holderness': 418,
#   'mothman': 419,
#   'rickyfinn': 420,
#   'ZAP': 421,
#   'Zhoxush': 422,
#   'Kayakguy': 423,
#   'brewale4me': 424,
#   'mvanaskie13': 425,
#   'mlockman': 426,
#   'NeroFiddled': 427,
#   'DavoleBomb': 428,
#   'MarkQ617': 429,
#   'HardTarget': 430,
#   'Caveworm': 431,
#   'Fitzy01': 432,
#   'PatrickCT': 433,
#   '4liter': 434,
#   'kevin3046': 435,
#   'DrMullet': 436,
#   'NextBestThing': 437,
#   'generallee': 438,
#   'Lettice123': 439,
#   'singletary': 440,
#   'jjamadorphd': 441,
#   'Scott17Taylor': 442,
#   'BeerAndGasMasks': 443,
#   'BrownAleBollocks': 444,
#   'BeerWithMike': 445,
#   'NiceTaps': 446,
#   'TheBrewo': 447,
#   'TheCondor': 448,
#   'CraftyHusker': 449,
#   'rangerred': 450,
#   'Gavage': 451,
#   'AgentMunky': 452,
#   'searsclone': 453,
#   'jmbranum': 454,
#   'Charliethebrit': 455,
#   'dcotom': 456,
#   'ReviewInABag': 457,
#   'goodsuds': 458,
#   'dueserdo': 459,
#   'Burly': 460,
#   'OldSwampy': 461,
#   'the_awesometeer': 462,
#   'BEERchitect': 463,
#   'Spikester': 464,
#   'Billolick': 465,
#   'PhilHeinricke': 466,
#   'transitionbikes93': 467,
#   'CIBoy10': 468,
#   'gandres': 469,
#   'Md35': 470,
#   'SamuelMiller': 471,
#   'Libeertarian': 472,
#   'RJLarse': 473,
#   'dbrauneis': 474,
#   'Redneckwine': 475,
#   'zander4dawin': 476,
#   'Act25': 477,
#   'ryan1788a5': 478,
#   'Zorro': 479,
#   'TheRealBigC': 480,
#   'vkv822': 481,
#   'Bockrules': 482,
#   'Gr8-Nate': 483,
#   'TheMarkE': 484,
#   'Jugs_McGhee': 485,
#   'Fatehunter': 486,
#   'wac9': 487,
#   'Kendo': 488,
#   'Hoptometrist': 489,
#   'MadScientist': 490,
#   'twiggamortis420': 491,
#   'Brenden': 492,
#   'RblWthACoz': 493,
#   'zeff80': 494,
#   'barczar': 495,
#   'Jocose47': 496,
#   'harpo111': 497,
#   'tuathaunderhill': 498,
#   'NorthernMichiganLogan': 499,
#   'KentT': 500,
#   'Ob512316': 501,
#   'OldSchoolMike': 502,
#   'TBDave': 503,
#   'Troy-Hawaii': 504,
#   'Bito24': 505,
#   'Misanthropy_Sipping': 506,
#   'Prager62': 507,
#   'buschbeer': 508,
#   'donspublic': 509,
#   'RockySasquatch': 510,
#   'chlsmith': 511,
#   'Retroman40': 512,
#   'car2052': 513,
#   'KYGunner': 514,
#   'Schwarzwald': 515,
#   'yumyumbrew': 516,
#   'screamking': 517,
#   'GossageBrewery': 518,
#   'patpbr': 519,
#   'baos': 520,
#   'somaohio': 521,
#   'keeganfrank': 522,
#   'CAMRAhardliner': 523,
#   'Tripel_Threat': 524,
#   'rhoadsrage': 525,
#   'TreyIsWilson': 526,
#   'SerialTicker': 527,
#   'maximum12': 528,
#   'Huhzubendah': 529,
#   'andrewjraab': 530,
#   'tectactoe': 531,
#   'BeastOfTheNortheast': 532,
#   'Wattie83': 533,
#   'smcolw': 534,
#   'GreesyFizeek': 535,
#   'Tucquan': 536,
#   'Lingenbrau': 537,
#   'ClePaul': 538,
#   'Scrapss': 539,
#   'BeerBatteredPhish': 540,
#   'Uniobrew31': 541,
#   'Sipchue': 542,
#   'nukem5': 543,
#   'Mister_Falcon': 544,
#   'jifigz': 545,
#   'paulhargus': 546,
#   'jmdrpi': 547,
#   'GStone899': 548,
#   'Nosquatch': 549,
#   'Baumer': 550,
#   'atniup': 551,
#   '88caprice': 552,
#   'lwillitz': 553,
#   'carlborch': 554,
#   'GRPunk': 555,
#   'FanofHefe': 556,
#   'kbeals': 557,
#   'bozebus17': 558,
#   'mjohn27603': 559,
#   'LampertLand': 560,
#   'Phyl21ca': 561,
#   'decimator': 562,
#   'wordemupg': 563,
#   'CrazyMike': 564,
#   'xuptygm': 565,
#   'atigerlife': 566,
#   'berley31': 567,
#   'biegaman': 568,
#   'terryeckmeier': 569,
#   'MisterClean': 570,
#   '1759Girl': 571,
#   'BDTyre': 572,
#   'humuloner22': 573,
#   'blackie': 574,
#   'brewdude1982': 575,
#   'cosmicevan': 576,
#   'kneeland': 577,
#   'tdm168': 578,
#   'smellandsip37': 579,
#   'jsanford': 580,
#   'Onenote81': 581,
#   'wcudwight': 582,
#   'BieresDesMoines': 583,
#   'Jason': 584,
#   'ChainGangGuy': 585,
#   'elNopalero': 586,
#   'BucannonXC5': 587,
#   'maddogruss': 588,
#   'Rick5150': 589,
#   'Cavanaghty': 590,
#   'justintcoons': 591,
#   'SawDog505': 592,
#   'chrishiker1409': 593,
#   'Chickenhawk9932': 594,
#   'wattoclone': 595,
#   'raizin': 596,
#   'LF_Evan': 597,
#   'HorseheadsHophead': 598,
#   'utopiajane': 599,
#   'tempest': 600,
#   'DoubleMalt': 601,
#   'ajm5108': 602,
#   'jzeilinger': 603,
#   'crisis1290': 604,
#   'kgammell1': 605,
#   'MisledTitan': 606,
#   'bobfinkenaur': 607,
#   'Samp01': 608,
#   'jhartley': 609,
#   'jzlyo': 610,
#   'Extrajoker00': 611,
#   'StaveHooks': 612,
#   'Hopswagger': 613,
#   'JuicesFlowing': 614,
#   'kdawg105': 615,
#   'keethrax': 616,
#   'JRed': 617,
#   'sixtysixpixistix': 618,
#   'Nerudamann': 619,
#   'thegodfather1076': 620,
#   'sixerofelixir': 621,
#   'yesyouam': 622,
#   'Meisterlol': 623,
#   'TheWhiskerReview': 624,
#   'Franz4': 625,
#   'sethmeister': 626,
#   'Manta200': 627,
#   'Siriusfisherman': 628,
#   'Brad007': 629,
#   'hopsputin': 630,
#   'SmashAdams': 631,
#   'Jwale73': 632,
#   'MacMalt': 633,
#   'LeRose': 634,
#   'Parmesan': 635,
#   'Todd': 636,
#   'Mugman8': 637,
#   'Amendm': 638,
#   'sulldaddy': 639,
#   'KRug': 640,
#   'yuriyt': 641,
#   'farrago': 642,
#   'atr2605': 643,
#   'DFMCapeCod': 644,
#   'mikesgroove': 645,
#   'Rifugium': 646,
#   'coalcracker': 647,
#   'Buggies': 648,
#   'BuxMontBeerLover': 649,
#   'Clydesdale': 650,
#   'Reidrover': 651,
#   'WesWes': 652,
#   'hdofu': 653,
#   'Durge': 654,
#   'mralphabet': 655,
#   'Jamesk55': 656,
#   'BretSikkink': 657,
#   'treque': 658,
#   'allengarvin': 659,
#   'gpogo': 660,
#   'Kaitekiyoukai': 661,
#   'Yuuki': 662,
#   'crob3888': 663,
#   'maxifunk777': 664,
#   'Hop_God': 665,
#   'Rollzroyce21': 666,
#   'ZakFaruki': 667,
#   'Dainslaif': 668,
#   'Furlinator': 669,
#   'DoubleJ': 670,
#   'mactrail': 671,
#   'Jamesthebrit': 672,
#   'TrappistJohnMD': 673,
#   'projectflam86': 674,
#   'curasowa': 675,
#   'TheDeuce': 676,
#   'Avagadro': 677,
#   'majesticsock': 678,
#   'doctchad': 679,
#   'MTNboy': 680,
#   'wiseguy142': 681,
#   'animal69': 682,
#   'Bitterbill': 683,
#   'MountianBrews': 684,
#   'Impetuous': 685,
#   'willsail4beer': 686,
#   'dwarvenfriend': 687,
#   'chumba526': 688,
#   'einmt33': 689,
#   'JohnGalt1': 690,
#   'nghab': 691,
#   'RedChrome': 692,
#   'froghop': 693,
#   'therica': 694,
#   'kgotcher': 695,
#   'BigBry': 696,
#   'loren01': 697,
#   'ElGordo': 698,
#   'charlesw': 699,
#   'SkeeterHawk': 700,
#   'kbub6f': 701,
#   'GClarkage': 702,
#   'daliandragon': 703,
#   'willic': 704,
#   'GarthDanielson': 705,
#   'Apellonious': 706,
#   'jcbogantes': 707,
#   'marley2112': 708,
#   'SiriusBock': 709,
#   'rinhaak': 710,
#   'cagocubs': 711,
#   'tapman': 712,
#   'mpcrump': 713,
#   'secondtooth': 714,
#   'Sweetmambyjamby': 715,
#   'TheViolator666': 716,
#   'cameraready': 717,
#   'Wasatch': 718,
#   'tmitch75': 719,
#   'JamesS': 720,
#   'brewdlyhooked13': 721,
#   'MuenchenerKindl': 722,
#   'blitheringidiot': 723,
#   'BitteBier': 724,
#   'shbobdb': 725,
#   'karst': 726,
#   'richkrull': 727,
#   'Morey': 728,
#   'bgildea': 729,
#   'cdkrenz': 730,
#   'mikereaser': 731,
#   'tjd112': 732,
#   'MadTown1000': 733,
#   'asabreed': 734,
#   'mwa423': 735,
#   'hustlesworth': 736,
#   'BitterPachyderm': 737,
#   'ruckus232': 738,
#   'porterwoobie': 739,
#   'Pauly2X': 740,
#   'bsend': 741,
#   'ATLbeerDog': 742,
#   'Shumista': 743,
#   'Seanibus': 744,
#   'tedsox31': 745,
#   'seedyone': 746,
#   'DiabolikDUB': 747,
#   'Floydster': 748,
#   'SurlyDuff': 749,
#   'ClockworkOrange': 750,
#   'illidurit': 751,
#   'Deuane': 752,
#   'yourefragile': 753,
#   'Offa': 754,
#   'TheLongBeachBum': 755,
#   'EMV': 756,
#   'Smakawhat': 757,
#   'JohnCap523': 758,
#   'IronLover': 759,
#   'drtth': 760,
#   'larryi86': 761,
#   'jancona': 762,
#   'Joecaddie': 763,
#   'Mindsquall': 764,
#   'SebD': 765,
#   'Digimaika2': 766,
#   'spinrsx': 767,
#   'thehyperduck': 768,
#   'bylerteck': 769,
#   'bryehn': 770,
#   'liamt07': 771,
#   'TheHammer': 772,
#   'karait95': 773,
#   'allergictomacros': 774,
#   'Sammy': 775,
#   'EatsTacos': 776,
#   'GodOfBeer': 777,
#   'Derek': 778,
#   'Ironhand24680': 779,
#   'BeersNBars': 780,
#   'ChrisCage': 781,
#   'BuckyBeerBeaver': 782,
#   'Watershed': 783,
#   'JohnnyBarman': 784,
#   'JOaikido': 785,
#   'korguy123': 786,
#   'hopsolutely': 787,
#   'cratez': 788,
#   'heebes': 789,
#   'pootz': 790,
#   'madtappers': 791,
#   'bluemoonswoon': 792,
#   'prosper': 793,
#   'dnichols': 794,
#   'riversider76': 795,
#   'Bookseeb': 796,
#   'woemad': 797,
#   'Noxious26': 798,
#   'BigRedN': 799,
#   'brureview': 800,
#   'lic217': 801,
#   'dd43': 802,
#   'beerturf': 803,
#   'WhiteHillsStore': 804,
#   'BranfordBound': 805,
#   'Robwvu304': 806,
#   'Zonk': 807,
#   'dar482': 808,
#   'Treebs': 809,
#   'emerge077': 810,
#   'KDawg': 811,
#   'GbVDave': 812,
#   'aerozeppl': 813,
#   'jrallen34': 814,
#   'MasterSki': 815,
#   'Bubba83': 816,
#   'Kegatron': 817,
#   'diabecktic': 818,
#   'Arbitrator': 819,
#   'trbergman': 820,
#   'scruffwhor': 821,
#   'samie85': 822,
#   'Florida9': 823,
#   'MrMcGibblets': 824,
#   'wspscott': 825,
#   'nickynick': 826,
#   'JoshuaJ': 827,
#   'mday': 828,
#   'infideltaco': 829,
#   'malcontent': 830,
#   'mick303': 831,
#   'mintjellie': 832,
#   'Bobdope': 833,
#   'Brent': 834,
#   'drinkininthewood': 835,
#   'Mandrake': 836,
#   'IronDjinn': 837,
#   'kazaxson': 838,
#   'donmonkey1': 839,
#   'jettjon': 840,
#   'DarrellK': 841,
#   'budgood1': 842,
#   'mntlover': 843,
#   'breardon1776': 844,
#   'DocRoc': 845,
#   'Vestlake': 846,
#   'richj1970': 847,
#   'STKPICR0720': 848,
#   'pkalix': 849,
#   'BBThunderbolt': 850,
#   'Briken': 851,
#   'DirtyPenny': 852,
#   'nebula1999': 853,
#   'BMac17': 854,
#   'Halcyondays': 855,
#   'Gmann': 856,
#   'jaialainut': 857,
#   'DaveHS': 858,
#   'stakem': 859,
#   'letsgopens': 860,
#   'goldold': 861,
#   'treehugger02010': 862,
#   'shirfan': 863,
#   'Tallboy': 864,
#   'outdoorbrewer': 865,
#   'barrettds': 866,
#   'mentor': 867,
#   'Ricochet': 868,
#   'rabidawg': 869,
#   'GreatPondBrewer': 870,
#   'RaulMondesi': 871,
#   'ricke49': 872,
#   'boralyl': 873,
#   'PaulStoneAnchor': 874,
#   'NWer': 875,
#   'oregonskibum': 876,
#   'dukew456': 877,
#   'RedDiamond': 878,
#   'z_21': 879,
#   'hman43': 880,
#   'JeffreyPaulBradt': 881,
#   'barknee': 882,
#   'CNoj012': 883,
#   'gatornation': 884,
#   'jpro': 885,
#   'RyanDe680': 886,
#   'wolandjr': 887,
#   'MEPBlue': 888,
#   'Spaghett': 889,
#   'ngeunit1': 890,
#   'SFGuy187': 891,
#   'lechroy': 892,
#   'berkey': 893,
#   'augustgarage': 894,
#   'mjl21': 895,
#   'nickd717': 896,
#   'popery': 897,
#   'willjschmidt': 898,
#   'DIYMonkey': 899,
#   'Agriverbear': 900,
#   'ilikebeer03': 901,
#   'dhannes': 902,
#   'TMoney2591': 903,
#   'CaptainIPA': 904,
#   'objectivemonkey': 905,
#   'mynie': 906,
#   'svraines': 907,
#   'BeerBelcher': 908,
#   'circuitmonkey': 909,
#   'brewQ': 910,
#   'cokes': 911,
#   'BigGold': 912,
#   'fjrobinson44': 913,
#   'Jacurdy60': 914,
#   'lighthabit': 915,
#   'TheFlern': 916,
#   'suspect': 917,
#   'BowserBrew': 918,
#   'philbertk': 919,
#   'BuckeyeNation': 920,
#   'TheBishop': 921,
#   'ppoitras': 922,
#   'djeucalyptus': 923,
#   'Slats': 924,
#   'jdhilt': 925,
#   'Hanhwaeaglesv2': 926,
#   'FLima': 927,
#   'magictacosinus': 928,
#   'eduardolinhalis': 929,
#   'Mellonius': 930,
#   'endovelico': 931,
#   'AlexLMS': 932,
#   'fx20736': 933,
#   'bushbeer75': 934,
#   'DannyDan': 935,
#   'Schmidts': 936,
#   'bullwinkle88': 937,
#   'Knapp85': 938,
#   'almychristopher': 939,
#   'drxandy': 940,
#   'tmoneyba': 941,
#   'joemcgrath27': 942,
#   'peensteen': 943,
#   'TheSevenDuffs': 944,
#   'mrmanning': 945,
#   'gboy515duo': 946,
#   'h00dak': 947,
#   'JMH_': 948,
#   'ommegangpbr': 949,
#   'Phatz': 950,
#   'BeerAdvocate': 951,
#   'mdaschaf': 952,
#   'barleywinefiend': 953,
#   'dirtylou': 954,
#   'TheGent': 955,
#   'garymuchow': 956,
#   'Ahypercube': 957,
#   'BPVandenbroek': 958,
#   'Organdrew': 959,
#   'TheDoctor': 960,
#   'Poljazz22': 961,
#   'CanadianBacon': 962,
#   'lgmol': 963,
#   'FrostBlast': 964,
#   '4ster': 965,
#   'Jake-northrup': 966,
#   'flaskman': 967,
#   'thebeers': 968,
#   'LennyOvies': 969,
#   'Pexkool': 970,
#   'nano': 971,
#   'Gusler': 972,
#   'russpowell': 973,
#   'tesguino': 974,
#   'Jredner': 975,
#   'Gueuzedude': 976,
#   'fido': 977,
#   'Pepeton': 978,
#   'Shebeckastan': 979,
#   'OWSLEY069': 980,
#   'Mounty4Life': 981,
#   'ONovoMexicano': 982,
#   'MattyG85': 983,
#   'barnzy78': 984,
#   'beerguy04': 985,
#   'handmuffin': 986,
#   'LilBeerDoctor': 987,
#   'swim': 988,
#   'DaveandMargo': 989,
#   'Drew_wilks81': 990,
#   'Bashlet': 991,
#   'Frozensoul327': 992,
#   'Svart': 993,
#   '5thOhio': 994,
#   'dgilks': 995,
#   'ADZA': 996,
#   'Scott29': 997,
#   'BDIMike': 998,
#   'BlackDog': 999,
#   ...},
#  {'Traditional Lager': 0,
#   'Lager': 1,
#   "George Killian's Irish Red": 2,
#   'Toasted Lager': 3,
#   'Amber': 4,
#   'Original Honey Brown Extra Rich Lager (Beer Brewed With Honey)': 5,
#   'Third Shift Amber Lager': 6,
#   'Riverwest Stein Beer': 7,
#   'Vinyl': 8,
#   'Barking Squirrel Lager': 9,
#   'Redbridge': 10,
#   'ZiegenBock Amber': 11,
#   'Coney Island Lager': 12,
#   'Grain Belt Nordeast': 13,
#   'Wisconsin Amber': 14,
#   "Rickard's Red": 15,
#   'Creemore Springs Premium Lager': 16,
#   'Red Oak': 17,
#   'Lashes Lager': 18,
#   'Texas Red Amber Lager': 19,
#   'Point Classic Amber': 20,
#   'Sleeman Honey Brown Lager': 21,
#   'Winter Skål': 22,
#   "Schell's Dark": 23,
#   'Starr Hill Jomo Lager': 24,
#   'Colorado Native Amber Lager': 25,
#   'Michelob Honey Lager': 26,
#   'Ornery Amber': 27,
#   'Yard Sale Winter Lager': 28,
#   'Budweiser Freedom Reserve Red Lager': 29,
#   'Pre-Prohibition Style Lager': 30,
#   "Trader Jose's Dark Lager": 31,
#   'Session Fest': 32,
#   'LTD Series - 05': 33,
#   'Budweiser 1933 Repeal Reserve Amber Lager': 34,
#   'Hudepohl Amber Lager': 35,
#   '100th Meridian': 36,
#   "Lil' Wheezy": 37,
#   'American Amber': 38,
#   'Preseason Lager': 39,
#   'Rochester Red': 40,
#   'Cypress Honey Lager': 41,
#   'Ruby Lager': 42,
#   'Cold Brew Coffee Lager': 43,
#   'Kutztown Lager': 44,
#   'Dundee Irish Red Lager': 45,
#   'Shipping Out of Boston': 46,
#   'Muddy Creek Lager': 47,
#   'Stegmaier Amber Lager': 48,
#   'Mojave Red': 49,
#   'Asahi Select': 50,
#   'Lagerithm': 51,
#   'Aruba Red': 52,
#   'Highland Lager': 53,
#   'Dam Lager': 54,
#   'Auburn Lager': 55,
#   'Gila Monster Amber Lager': 56,
#   'El Oso': 57,
#   'The All-Weather DELCO Lager': 58,
#   'Red Leaf Smooth Red Lager': 59,
#   'Tap Room No. 21 Copper Lager': 60,
#   'Kokanee Gold': 61,
#   'Dock Time': 62,
#   'Safari Amber': 63,
#   'Queens Lager': 64,
#   'Half Acre Lager': 65,
#   'Millennium Buzz Hemp Beer': 66,
#   'Founding Fathers Lager': 67,
#   'Rebellion': 68,
#   'Crush Beer': 69,
#   'Genesee Red Lager': 70,
#   'Coastal Common': 71,
#   "Season's Best Winter Lager": 72,
#   'Island Draught Amber': 73,
#   'Toast (Slightly Burnt)': 74,
#   'Pinsetter': 75,
#   'Devils Lake Red Lager': 76,
#   'Cave City Lager': 77,
#   'Killarney': 78,
#   'Super Bock Abadia': 79,
#   'John Labatt Red Amber': 80,
#   'Wild Oats Series No. 9 - Winterbrewed': 81,
#   'Pocono Lager': 82,
#   'Chrome Satan': 83,
#   'Smuttlabs Baja Hoodie': 84,
#   'Pretzel Assassin': 85,
#   'Rolling Rock Amber Lager': 86,
#   'Grande Cuvée Réserve De Noël': 87,
#   'Saranac Irish Lager': 88,
#   'Tijuana Morena': 89,
#   'RT Lager': 90,
#   'Copperpop': 91,
#   'Badger Club Beer': 92,
#   "Fegley's Amber Lager": 93,
#   'Laker Red': 94,
#   'Kross Golden Ale': 95,
#   'Dogtown Brown': 96,
#   'Iron City Amber': 97,
#   'Avenel Amber': 98,
#   "Henry Weinhard's Dark": 99,
#   'Dirtyface Amber Lager': 100,
#   'Amber Lager': 101,
#   'Ramstein Amber Lager': 102,
#   'Rough Rider Red Lager': 103,
#   'Primátor Polotmavý Märzen': 104,
#   'Honey Brown': 105,
#   'Faxe Red': 106,
#   'Mallee Bull Heavy': 107,
#   'Cusqueña Roja': 108,
#   'Brutus': 109,
#   'Honey Brown Lager': 110,
#   'Smoove': 111,
#   'Dos Equis Roja': 112,
#   'Bernard Amber Lager': 113,
#   'Beck’s Amber Lager': 114,
#   'Craft American Lager': 115,
#   "Quinn's Amber Lager": 116,
#   'Broken Auger Lager': 117,
#   "Wild Bill's Wild Rice Lager": 118,
#   'Backyard Brew Lawn Mower': 119,
#   'Rooster Lager': 120,
#   'Southside Lager': 121,
#   "Ol' Glory": 122,
#   'Holiday Honey': 123,
#   'Rolling Rock Red': 124,
#   'Sequoia Amber Lager': 125,
#   'Modelo Ambar': 126,
#   'Superior Rubia': 127,
#   'Old Fred': 128,
#   'Hurry Hard': 129,
#   'Grand River Red': 130,
#   'Skipjack Amber': 131,
#   'La Crosse Amber Lager (Session Series)': 132,
#   'Crimson Lager': 133,
#   "Kickin' Back Amber Lager": 134,
#   'Generosity': 135,
#   'Freedom Road': 136,
#   'De Koninck Anno 1833': 137,
#   'Copper Flask': 138,
#   "Clancy's Red": 139,
#   'Red Lager': 140,
#   'Red Oktober': 141,
#   'Hudepohl Pure Lager': 142,
#   'Hitachino Nest Lager': 143,
#   'Black Diamond Lager': 144,
#   'CHOPFAB AMBER': 145,
#   'Copperpoint Lager': 146,
#   'Cacildis': 147,
#   'PC Honey Red': 148,
#   'Hangry Bock': 149,
#   'Hinano Ambree': 150,
#   'Red Bank Dark Lager': 151,
#   'Ungurio Kojos (Eel Legs)': 152,
#   'Long Play (LP) IPL': 153,
#   'Red Rock': 154,
#   'Summerfest Lager': 155,
#   "Corky's Memphis Brew": 156,
#   "Original Joe's Honey Brown Lager": 157,
#   'Frogman Lager': 158,
#   'Red Dragon Red Lager': 159,
#   'Capitão Senra': 160,
#   'Lazy Daze Amber Lager': 161,
#   'Rouge': 162,
#   'Krimson King': 163,
#   'Ghost Lights Amber Lager': 164,
#   'Under The Red Light': 165,
#   'Stamp Hammer Oak Aged Amber Lager': 166,
#   "Rickard's Red Session Lager": 167,
#   'Bohemia 1835': 168,
#   'Honey Lager': 169,
#   'Show Me Amber Lager': 170,
#   'Manila': 171,
#   'Pecos Amber': 172,
#   'Saloon Juice': 173,
#   'Red Light Lager': 174,
#   'Snakes & Shamrocks': 175,
#   'Albino Rhino Signature Lager': 176,
#   'Red Zone Lager': 177,
#   'Sagamore Dark Lager': 178,
#   'Lake Sandy Rye': 179,
#   'Brenna A': 180,
#   'BarrelShed No.1': 181,
#   'Freddy D Lager': 182,
#   'Red Dawn': 183,
#   'Winter Warmer Amber Lager': 184,
#   'S:t Eriks & Mathias Dahlgren Påsköl': 185,
#   'Lumberyard Amber': 186,
#   'Dark': 187,
#   'La Fuerza Borracho': 188,
#   'Dark Chocolate Lager': 189,
#   'Red Brixx Ale': 190,
#   'Game On Grand Stand Amber Lager': 191,
#   'Rubber Neck Red': 192,
#   'Red Wing Lager': 193,
#   'Winter Lager': 194,
#   'Frostbite Winter Lager': 195,
#   'Baltika Big Mug Amber (Bolshaya Kruzhka)': 196,
#   'Abalus Amber': 197,
#   'Karel IV': 198,
#   'Ožujsko Amber': 199,
#   'Redland Lager': 200,
#   'Ice Cap Lager': 201,
#   'PA to LA': 202,
#   'Boss Amber Lager': 203,
#   'Sieben Lager': 204,
#   'Dawn Patrol': 205,
#   'Loose Tongue Lager': 206,
#   'Sour Cran-Cherry Queen': 207,
#   'Bug Zapper Super Lager': 208,
#   'Irish Red Lager': 209,
#   'High Barbary': 210,
#   'Montana Logger': 211,
#   'Southern Passion': 212,
#   'Wild Monkeys - Malt Biker': 213,
#   'Harboe Red Beer': 214,
#   'Paulistania Vermelha': 215,
#   'Redact Amber Lager': 216,
#   'Coney Island Freaktoberfest': 217,
#   'Luchabrew Mexican Lager': 218,
#   'Meggapilz': 219,
#   'Red Nitro Ale': 220,
#   'Togi Amber Lager': 221,
#   'Pure Bred': 222,
#   'Axe Men Red Ale': 223,
#   'Princess': 224,
#   '1031 Zombie Lager': 225,
#   'Deer Camp': 226,
#   'Megra Nodelo': 227,
#   'Lallas Lager': 228,
#   'Seasonal Brew': 229,
#   'Luverne Lager': 230,
#   'Punchestown Irish Red Lager': 231,
#   'Grande Rivière': 232,
#   'Paupack Amber Lager': 233,
#   'Ski Tan': 234,
#   'The Little Red Pils': 235,
#   'Galway Hooker Amber Lager': 236,
#   'Falcon Koppar': 237,
#   'All Mountain Amber': 238,
#   'Low Country Lager': 239,
#   'Amber Lager Källare No 9': 240,
#   'Gimme A Kiss': 241,
#   'Rushing Rapids Red (Insider Beer)': 242,
#   "Plucker's Amber Lager": 243,
#   'Mixed Forecast - Still Raining Dark Lager': 244,
#   'Cheer': 245,
#   'Gon-Ta-Nort': 246,
#   'LagerShed Darker': 247,
#   'Imperial Red': 248,
#   'Saddle Rock Red Lager': 249,
#   'Basica': 250,
#   'Castana Urbana Mexican Lager': 251,
#   'Cool Ridge Lager': 252,
#   'Lost Lake Naturally Brewed Amber Lager': 253,
#   'Varsity Hall Red Ale': 254,
#   'Vienna Horizon Lager': 255,
#   'Kellager': 256,
#   'Zenata': 257,
#   'Exklusiv': 258,
#   'High Country Lager': 259,
#   'Wagner Kupferstich Rotbier': 260,
#   'Tiger Black Strong': 261,
#   'Detour': 262,
#   '1554': 263,
#   'Guinness Black Lager': 264,
#   'Creamy Dark': 265,
#   'Blackened Voodoo': 266,
#   'Heineken Dark Lager': 267,
#   'Baltika #4 Original (Dark)': 268,
#   'St. Pauli Girl Special Dark': 269,
#   'Fischer Tradition Amber': 270,
#   'Death & Taxes': 271,
#   'San Miguel Dark Lager': 272,
#   'Budweiser Budvar Czech Dark Lager': 273,
#   'Dark Lager': 274,
#   'Efes Dark': 275,
#   'Beerlao Dark': 276,
#   'Black Licorice Lager': 277,
#   'LTD Series - 06': 278,
#   'Bernard Cerne (Dark)': 279,
#   'El Steinber Dark Lager': 280,
#   'Alhambra Negra': 281,
#   'Kelso Nut Brown Lager': 282,
#   'Praga Dark Lager': 283,
#   'Pils Noir': 284,
#   'Dark Horse Lager': 285,
# ...
#   'Loonar Eclipse': 449,
#   'La Cocina': 450,
#   'Arboga Mörk Lager': 451,
#   'Koronet Stout': 452,
#   'Witching Hour Black Lager': 453,
#   'Bavaria Oud Bruin': 454,
#   'Chatiemac Black Lager': 455,
#   'Eriksberg Påsköl': 456,
#   'Karlovar Cerny Granat': 457,
#   'Nothing Is Certain': 458,
#   'Dreams of Tomorrow': 459,
#   'Pretty Metal': 460,
#   'Weifert': 461,
#   'Crushed To Death': 462,
#   'Potash Pivo': 463,
#   'Polotmavy': 464,
#   'New Moon': 465,
#   'Oblivion': 466,
#   'Ožujsko Rezano': 467,
#   'Miodne': 468,
#   'Bernard Semi-dark Lager (polotmavy Lezak)': 469,
#   '93x Beer Of The Dark': 470,
#   'Christmas Special': 471,
#   'Artesian Dark Ale': 472,
#   'Stolichnoe Black': 473,
#   'Jóla Kaldi': 474,
#   'Ariana Tumno (Dark)': 475,
#   'Coruja Noctua Dark': 476,
#   'Vinterlager': 477,
#   'Noteckie Eire': 478,
#   'Oppler Brună': 479,
#   'Skopsko Temno': 480,
#   'Cherry Bomb': 481,
#   'Three Hearts Påskebrygd 6,0': 482,
#   'El Moreno': 483,
#   'Virunga Mist': 484,
#   'Skördeöl': 485,
#   'Arctic Dark': 486,
#   'Bratislavský Bubák': 487,
#   'Barkhatnoye': 488,
#   'Tmavy Lezak Nefiltrovany': 489,
#   'Black Forest': 490,
#   'Spring': 491,
#   'Oh Vienna': 492,
#   'Czech Dark': 493,
#   'Kruger Dunkel': 494,
#   'Rusalka': 495,
#   'Black Diamond': 496,
#   'Dark Unfiltered (Temnoe Unfiltered)': 497,
#   'Tempo': 498,
#   'České Temný': 499,
#   'Another Beer': 500,
#   'Brake Czech': 501,
#   'Bonspiel Brown': 502,
#   'Lakrits': 503,
#   'Burkhart': 504,
#   'Litovel Premium Schwarzbier': 505,
#   'Cornelius Dunkel': 506,
#   'Boxer Brunette': 507,
#   'ZlatoPražske Dark': 508,
#   'Clan Gun Scottish Lager': 509,
#   'Plato 14': 510,
#   'The Wolfgang Chocolate Lager': 511,
#   'Vyškovské Tmavý Džbán': 512,
#   'Lying Idle': 513,
#   'Flowers at Dusk': 514,
#   'Dock Lager': 515,
#   'Proper Lagered': 516,
#   'Steiger 11% Tmavý': 517,
#   'Short Swartz': 518,
#   'Lager Brune Légère': 519,
#   'Night Game': 520,
#   'Defenestration Czech Dark Lager': 521,
#   'Astika Tumno': 522,
#   'Bier Ist Gesund Zu Jeder Stund (Beer is Healthy at Every Hour)': 523,
#   'I’m So Horny!': 524,
#   'Cimmerian': 525,
#   'Starlite Black Nite Lager': 526,
#   'I Dunkeled In My Pants': 527,
#   'Raw Series Black Lager': 528,
#   'Samuel Adams Octoberfest': 529,
#   'Ayinger Oktober Fest-Märzen': 530,
#   'Oktoberfest Märzen': 531,
#   'Spaten Oktoberfestbier': 532,
#   'Oktoberfest': 533,
#   'Festbier': 534,
#   'Hacker-Pschorr Oktoberfest Märzen': 535,
#   'Hofbräu Oktoberfestbier': 536,
#   'Octoberfest Beer': 537,
#   'Shiner Märzen-Style Oktoberfest': 538,
#   'Staghorn Octoberfest': 539,
#   'Hoss Oktoberfest Lager': 540,
#   'Dogtoberfest': 541,
#   'Goose Fest Bier': 542,
#   "Beck's Oktoberfest": 543,
#   'Munsterfest': 544,
#   'Märzen': 545,
#   'Oaktoberfest': 546,
#   'Warsteiner Premium Oktoberfest': 547,
#   "Bob's '47 Oktoberfest": 548,
#   'Oktoberfest Bier (Oktoberfest Wiesn)': 549,
#   'Dead Ringer': 550,
#   'Copper Legend Octoberfest': 551,
#   'Atom Smasher': 552,
#   'Saranac Our Octoberfest German Style Lager': 553,
#   'Oktober Fest': 554,
#   'OktoberFish': 555,
#   'Life On Märzen': 556,
#   'Fest Märzen Lager': 557,
#   "Schell's Oktoberfest": 558,
#   'Oktoberfest Lager Beer': 559,
#   'Barktoberfest': 560,
#   'Clawhammer': 561,
#   'Dundee Oktoberfest': 562,
#   'Tuberfest': 563,
#   'Penn Oktoberfest': 564,
#   'Oktoberfest Märzen Style Lager': 565,
#   'Mad Bishop': 566,
#   'Dominion Octoberfest!': 567,
#   'Point Oktoberfest': 568,
#   'Noble Chaos': 569,
#   'Octoberfest Lager': 570,
#   'Odell Oktoberfest': 571,
#   'Oktoberfest Beer': 572,
#   'Octoberfest (Märzen-Style) Lager': 573,
#   'Josephs Brau Oktoberfest': 574,
#   'Dragonhosen': 575,
#   'Karbachtoberfest': 576,
#   'Weltenburger Kloster Anno 1050': 577,
#   'Blöktoberfest': 578,
#   'Löwenbräu Oktoberfestbier': 579,
#   'FestBier': 580,
#   'Lager Town': 581,
#   'Oktoberfest (2020)': 582,
#   'Ok2berfest': 583,
#   'Mecktoberfest': 584,
#   'Festie Oktoberfest Lager (Heavy Rotation Series No. 07)': 585,
#   'Märzenbier': 586,
#   'Fest': 587,
#   'Voll Damm': 588,
#   'Dinkelacker Oktoberfestbier Märzen': 589,
#   'Oachkatzlschwoaf ("O-Katz")': 590,
#   'Original Munchner Hochzeitsbier Von 1810': 591,
#   'Octoberfest': 592,
#   'Saratoga Lager': 593,
#   'Altenmünster Oktoberfest': 594,
#   'German Style Lager': 595,
#   'Oktoberfest Festbier Lager': 596,
#   'Karl Strauss Oktoberfest Beer': 597,
#   'Hop Harvest Oktoberfest': 598,
#   'Fifth & Vine Oktoberfest Marzen': 599,
#   'Afterburner': 600,
#   'Fest Devious': 601,
#   "Weissenohe Monk's Fest": 602,
#   'Newport Storm Oktoberfest Marzen Lager': 603,
#   'Weltenburger Kloster Winter-Traum': 604,
#   'Baltijos': 605,
#   'Oktofest': 606,
#   'Benediktiner Oktoberfest / Festbier': 607,
#   'Carver': 608,
#   'Rocktoberfest': 609,
#   'Oktoberfest Lager': 610,
#   'Augustiner Bräu Oktoberfestbier': 611,
#   'Gemuetlichkeit Oktoberfest': 612,
#   'Marzen': 613,
#   'Oktoberfest: Gemütlichkeit': 614,
#   'Stegmaier Oktoberfest': 615,
#   'Oktoberfest Märzen Lager': 616,
#   'Vida Y Muerte Muertzenbier': 617,
#   'Night Märzen': 618,
#   'Ramstein Oktoberfest': 619,
#   'Hösl Märzenbier': 620,
#   'Hofbräu Oktoberfest': 621,
#   'Tradition': 622,
#   'Hofbräu Festbier': 623,
#   'Special Edition - Oktoberfest Lager': 624,
#   'Memminger Gold': 625,
#   'AleSchmidt Oktoberfest': 626,
#   'Opa’s Oktoberfest': 627,
#   'Autumn Winds': 628,
#   "G'Suffa!": 629,
#   'Wolters Fest-Bier': 630,
#   'Märzen Oktoberfest': 631,
#   'Gold': 632,
#   '13.Five Ofest': 633,
#   'Augtoberfest': 634,
#   'Saranac Dark-tober(fest)': 635,
#   'OktoberBeast': 636,
#   'Kipona Fest': 637,
#   'Augustiner Bräu Märzen Bier': 638,
#   'Schadenfreude': 639,
#   'Treasure Fest Oktoberfest Lager': 640,
#   'DankeChain': 641,
#   'Zirkusfest': 642,
#   'Oktüberfest': 643,
#   'Schwandtoberfest': 644,
#   'Fall Lager': 645,
#   'Kalasöl': 646,
#   'O-toberfest': 647,
#   'Alpenkönig Gold Märzen': 648,
#   "Heileman's Old Style Oktoberfest": 649,
#   'Fest Beer': 650,
#   'Das Echte Märzen': 651,
#   'Série Signature Oktoberfest': 652,
#   'Schnitzengiggles Festbier': 653,
#   'Creekfestbier Lager': 654,
#   'Ayinger Kirta-Halbe': 655,
#   'VolksfestBier': 656,
#   'Bisonfest': 657,
#   'Fall Festival Lager': 658,
#   'Altoberfest': 659,
#   'Conchtoberfest': 660,
#   'Aries Märzen Oktoberfest': 661,
#   'Rhin’Ofest': 662,
#   'Bobtoberfest': 663,
#   'Dauntless': 664,
#   'Daura Märzen': 665,
#   'Licher Oktoberfest': 666,
#   'Rothaus Eis Zäpfle': 667,
#   '1810 Oktoberfest': 668,
#   'Oktoberfest Froggy Style Lager': 669,
#   'LTD Series - 07': 670,
#   'Gundertshausner Schnaitlbräu (Meisterbräu)': 671,
#   'Oktoberfest Brau': 672,
#   'Oktillion': 673,
#   'Hasenpfeffer Oktoberferst': 674,
#   'Oaktober Ale': 675,
#   'Oktöberface': 676,
#   'Gösser Märzen': 677,
#   'Casco Bay Oktoberfest': 678,
#   'Hawktoberfest': 679,
#   'Märzen Fest Bier': 680,
#   'Genesee Oktoberfest': 681,
#   'Late Harvest Lager': 682,
#   'Hoptoberfest': 683,
#   'Würzburger Oktoberfest': 684,
#   'Zepptemberfest': 685,
#   "O'Fest": 686,
#   'Duke Of Lager Fest Bier': 687,
#   'Leg Hound': 688,
#   'Oktoberfest Elchland Märzen Lager': 689,
#   'Groomer': 690,
#   'Fest Bier Märzen Lager': 691,
#   'Fruhauf': 692,
#   'Fest Amber Lager': 693,
#   'Saranac 1888 Octoberfest': 694,
#   'Creemore Springs Oktoberfest Lager': 695,
#   "Rickard's Lederhosen": 696,
#   'Hacker-Pschorr Superior Festbier': 697,
#   'Farm Table: Märzen': 698,
#   'Oktober Fuel': 699,
#   'Kloster Urstoff': 700,
#   'Bonfire Marzen Lager': 701,
#   'OktoberFiesta': 702,
#   'Brocktoberfest': 703,
#   'Revival Imperial Octoberfest': 704,
#   'Egger': 705,
#   'Farmers Daughter': 706,
#   'Zipfer Märzen': 707,
#   'Hoffmann Oktoberfest': 708,
#   'Harvest Moon Festbier Style Ale': 709,
#   'Mönchshof Weihnachts Bier': 710,
#   'Gobbler Lager': 711,
#   'Dam Straight Lager': 712,
#   'Rothaus Marzen Export': 713,
#   'Konstantin': 714,
#   'Hofbräu Märzen': 715,
#   'OctoFest': 716,
#   'Old Zahm Oktoberfest': 717,
#   'Saranac Marzenbier': 718,
#   'Red Hammer': 719,
#   'Klosterbräu Braunbier': 720,
#   'Waddle': 721,
#   'Savannah Fest Beer': 722,
#   "O'fest": 723,
#   'Guten Tag': 724,
#   'Winterfestbier': 725,
#   '#010 Patron Saint': 726,
#   'Das Besonbere Festbier': 727,
#   'Hissy Fit': 728,
#   'Trappist Festive Lager': 729,
#   "BJ's Octoberfest": 730,
#   'Hudepohl Oktoberfest Bier': 731,
#   'Erie Oktoberfest': 732,
#   'Brookside Beer': 733,
#   'Saint Norbert Amber': 734,
#   'Norden Hoch Oktoberfest': 735,
#   'Whisper': 736,
#   'Old World Oktoberfest': 737,
#   'Portsmouth Oktoberfest': 738,
#   'Negra Modelo': 739,
#   'Warsteiner Premium Dunkel': 740,
#   'Hofbräu Dunkel': 741,
#   'Ayinger Altbairisch Dunkel': 742,
#   "Beck's Dark": 743,
#   'Harpoon Dark': 744,
#   'Spaten Dunkel': 745,
#   'Eastside Dark': 746,
#   'Penn Dark': 747,
#   'Dark Cloud': 748,
#   'Weltenburger Kloster Barock Dunkel': 749,
#   'Kozel Černý (Dark)': 750,
#   'Asahi Black (Kuronama)': 751,
#   'Flensburger Dunkel': 752,
#   'Pious Monk Dunkel': 753,
#   'Garten Bräu Munich Dark': 754,
#   'Red Tape Lager': 755,
#   'König Ludwig Dunkel': 756,
#   'Barbarossa Double Dark Lager': 757,
#   'Mother In Lager': 758,
#   '31 Pumpkin Spiced Lager': 759,
#   'Ettaler Kloster Dunkel': 760,
#   'Holzar-Bier': 761,
#   'Augustiner Bräu Dunkel': 762,
#   'Dunkel Lager': 763,
#   'Saranac Lake Effect Lager': 764,
#   'Brown Hound Dunkel': 765,
#   'Neumarkter Lammsbräu (Organic) Dunkel': 766,
#   'Hirter Morchl': 767,
#   'Slingshot Dunkel': 768,
#   'GoldStar Dark Lager': 769,
#   'Gösser Dark Beer': 770,
#   'Jubilate': 771,
#   'Hacker-Pschorr Münchner Dunkel': 772,
#   'Saranac Long John Lager': 773,
#   'Fearless Youth': 774,
#   'Andechser Export Dunkel': 775,
#   'Original Münchner Dunkel': 776,
#   'Negra': 777,
#   'Victory Dark Lager': 778,
#   'Löwenbräu Premium Dark': 779,
#   'Arc Welder Dunkel Rye': 780,
#   "Cricket's Nocturne": 781,
#   'Veldensteiner Landbier': 782,
#   'Herrnbräu Jubiläums-Sud': 783,
#   'Warsteiner Weihnacht': 784,
#   'Jacobsen Dark Lager': 785,
#   'Eisenbahn Escura (Dunkel)': 786,
#   'Dark Beer / Kláster Tmavé 10%': 787,
#   'Reutberger Export Dunkel': 788,
#   'Dorfbier': 789,
#   'Lobkowicz Baron': 790,
#   'Bavaria Dark Beer': 791,
#   'G.G.': 792,
#   'Herrnbräu Publiner Dunkles Exportbier': 793,
#   'Landbier': 794,
#   'Bock Damm': 795,
#   "Hermann's Dark Lager": 796,
#   'Dunkels': 797,
#   'Fulton & Wood: Dark Traveler': 798,
#   'Landsknecht Bier': 799,
#   'Graf Stolberg Dunkel': 800,
#   'Creepy Uncle Dunkel': 801,
#   'Roslyn Beer (Dark Lager)': 802,
#   'Merlin Černy': 803,
#   'Temno Lasko': 804,
#   'Dead Eye Dunkel': 805,
#   'Tucher Urfränkisch Dunkel': 806,
#   'Dogbolter': 807,
#   'Soproni Fekete Démon': 808,
#   'Fässla Zwergla': 809,
#   'Mexicali Special Dark Beer': 810,
#   'Darkest Before Dawn': 811,
#   'Zötler Korbinian Dunkel': 812,
#   'Queen City Dunkel': 813,
#   'Dark Munich Lager': 814,
#   '1906 Black Coupage': 815,
#   'Munich Dunkel': 816,
#   'Scheyern Kloster-Export Dunkel': 817,
#   "Monteith's Celtic Red": 818,
#   'Moondoor Dunkel': 819,
#   'Double Dunkel': 820,
#   'Brunhilda': 821,
#   'E.T.A. (Ernst Theodor Amadeus) Hoffmann': 822,
#   'Dunkel Fester': 823,
#   'Golden Pheasant Dark': 824,
#   'Altenmünster Winterbier Dunkel': 825,
#   '100 Barrel Series #63 - Super Dark': 826,
#   'St. George Amber': 827,
#   'Krombacher Dunkel': 828,
#   'Altbayerisch': 829,
#   'Feldschlosschen Dunkel Perle': 830,
#   'Velebitsko Tamno Pivo': 831,
#   'Schweinsbräu Dunkel': 832,
#   'Weissenoher Bonifatius Dunkel': 833,
#   'Laughing Loon Lager': 834,
#   'Georg': 835,
#   'Farm Table: Dunkel': 836,
#   'Arcobräu Schloss Dunkel': 837,
#   'Kloster Kreuzberg Dunkel': 838,
#   'DAB Traditional': 839,
#   "Matso's Smokey Bishop": 840,
#   'Rio Bravo Special Dark Beer': 841,
#   'Altbairisch Dunkel': 842,
#   'Černovar Černé': 843,
#   'Dam Dark': 844,
#   'Last Fathom': 845,
#   'Dunkles Lagerbier': 846,
#   'Kaldi Dökkur': 847,
#   "Pott's Landbier": 848,
#   'Kaiser Doppelmalz': 849,
#   'Max Black': 850,
#   'Aufsesser Dunkel': 851,
#   'Oettinger Winterbier': 852,
#   'Allgäuer Urbairisch Dunkel': 853,
#   "Bob's Your Dunkel": 854,
#   'Dark Lager (Tmavý Le\x9eák)': 855,
#   'Brunette': 856,
#   'Arcobräu Dark Lager Beer': 857,
#   'Karmeliten Kloster Dunkel': 858,
#   'Munich Lager': 859,
#   'Therezópolis Ebenholz': 860,
#   "Voodoo's Child": 861,
#   'Černé Zámecké': 862,
#   '6-Korn Bier': 863,
#   'Kloster Dunkel': 864,
#   'Funkel Dunkel': 865,
#   'Hofbräu 1810 Prince Ludwig': 866,
#   'Valmiermuiža Tumšais (Valmiermuiža Dark)': 867,
#   'Keesmann Sternla Lager': 868,
#   'Klosterbier': 869,
#   'Riedenburger 5-Korn Ur-Bier': 870,
#   'Bakalář Tmavé Výčepní': 871,
#   'Munich Dark Lager': 872,
#   'Winter At Noon': 873,
#   'Black Mountain Beer': 874,
#   'Drak': 875,
#   'Schlappeseppel Dunkel': 876,
#   'Faust Schwarzviertler': 877,
#   'Ritter Trunk': 878,
#   'Robert Doms Munchensky': 879,
#   'Altfränkisches Bauernbier Dunkel': 880,
#   'Dewpoint Dunkel': 881,
#   'Vilniaus Alus Tamsusis (Dark)': 882,
#   'Vierzehnheiligen Nothelfer Trunk Export Dunkel': 883,
#   'Super Bock Selecção 1927 Munich Dunkel': 884,
#   'Lidskaye Aksamitnoye': 885,
#   'Blåkulla': 886,
#   'Vilkmergės Tamsusis (Vilkmerges Dark)': 887,
#   'Pistonhead Christmas Carol': 888,
#   'Premium Dark': 889,
#   'Ottakringer Dunkles': 890,
#   'Das Ambräusianum Dunkel': 891,
#   'Tegernsee Dunkel': 892,
#   'Gösser Stiftsbräu': 893,
#   "Schmidt's Dark": 894,
#   'Moosejaw Dunkel Lager': 895,
#   'Samson 1795 Original Czech Lager Dark': 896,
#   'Hofbrauhaus Berchtesgadener Dunkel': 897,
#   'Paulistânia Escura': 898,
#   'Dunkel Down': 899,
#   'Teerenpeli Laiskajaakko Luomu': 900,
#   'Kneitinger Dunkel Export': 901,
#   'Spezial Dunkel': 902,
#   'Focal Point Munich Dunkel': 903,
#   'Schinner Braunbier': 904,
#   'Samuel Adams Oaked Dunkel': 905,
#   'Alligator Blackened Lager': 906,
#   'Dunk': 907,
#   'Chocolate Dunkel': 908,
#   'Eichhof Hubertus Dunkel': 909,
#   'Gunsmith Dunkel Lager': 910,
#   'Dunkelnacht Dark Lager': 911,
#   '7 Stern Prager Dunkles': 912,
#   'New Town 11° Dark Lager': 913,
#   'Mahou Maestra Dunkel': 914,
#   'Memminger Lager Schwarz': 915,
#   'Cave Aged Barrel Aged No. 7': 916,
#   'Starobrno Cerne (Black)': 917,
#   'Litovel Dark': 918,
#   'Riegele Æchtes Dunkel': 919,
#   'Pan Tamni': 920,
#   'Dama Bier München': 921,
#   'Nocturne': 922,
#   'Nova Schin Munich': 923,
#   'Rasen Bier Dunkel': 924,
#   'Tell Tale Lager': 925,
#   'Ottakringer Gold Fassl Dunkles': 926,
#   'Rekord': 927,
#   'Dithmarscher Dunkel': 928,
#   'Kalla Tiders Ängöl': 929,
#   'Bavarian Dark Lager': 930,
#   'Alpirsbacher Klosterbräu Kloster Dunkel': 931,
#   'Paper Thin Walls': 932,
#   'Hammer Toss': 933,
#   'Koutský 14° Tmavý Speciál': 934,
#   'St. Georgenbräu Landbier': 935,
#   'Alley-oop Dunkel': 936,
#   'Buoy': 937,
#   'Einbecker Dunkel': 938,
#   'Galway Hooker Irish Dark Lager': 939,
#   'Munchner Dunkel': 940,
#   'Ott Obaladara': 941,
#   'Long Ship Lager': 942,
#   'Irsser Kloster-Urdunkel': 943,
#   'Vikingathor': 944,
#   'Schlossbier': 945,
#   'Schwarzer Bär': 946,
#   'Ahornberger Dunkel': 947,
#   'Red Rock Munich Dunkel': 948,
#   'Meisterbräu Vollbier Dunkel': 949,
#   'New Flame': 950,
#   'Landwehr Dunkles Landbier': 951,
#   'Teerenpeli Laiskajaakko': 952,
#   'Postwirts Dunkel': 953,
#   'Vulkan Dunkles': 954,
#   'Irish Beer': 955,
#   'Rieder Dunkel': 956,
#   'Driller Dunkel': 957,
#   'Ueli Robur Dunkel': 958,
#   'Altenmünster Dunkel': 959,
#   'Zwettler Dunkles': 960,
#   'D.U.N.K.L.E': 961,
#   'Plankstettener Dunkles': 962,
#   'Kingdom Dark Lager': 963,
#   'Richard Wagner Dunkel': 964,
#   'Junk In The Dunk': 965,
#   'Erinnerungstrunk': 966,
#   'Dirtbag Dunkel': 967,
#   'Eichhofener Spezial Dunkel': 968,
#   'Joh. Albrecht Kupfer': 969,
#   'Zeos Black': 970,
#   'Slow Chill Dunkel Lager': 971,
#   'Gerst': 972,
#   'Mile Of Munich': 973,
#   'Negra Royale': 974,
#   'Dachsenfranz Dunkel': 975,
#   'Night Surfing Munich Dunkel': 976,
#   'Aecht Schlenkerla Rauchbier Märzen': 977,
#   'Aecht Schlenkerla Rauchbier Urbock': 978,
#   'Smoke & Dagger': 979,
#   'Aecht Schlenkerla Eiche': 980,
#   'Aecht Schlenkerla Rauchbier Weizen': 981,
#   'Samuel Adams Cinder Bock': 982,
#   'Aecht Schlenkerla Fastenbier (Lentbeer)': 983,
#   'Fire In The Ham': 984,
#   'Coffee Smoke & Dagger': 985,
#   'Trösten': 986,
#   'Rauch Ür Bock': 987,
#   'Eisenbahn Rauchbier': 988,
#   'SWISHR - Cherry': 989,
#   "Ludwig's Revenge": 990,
#   'Rauchbier': 991,
#   'Saranac Rauchbier Smoked Lager': 992,
#   'Zwönitzer Rauchbier': 993,
#   'Punkrauch': 994,
#   'Roog': 995,
#   'Orange Swisher': 996,
#   'Chicago Smoke': 997,
#   'Bonfire Of The Valkyries': 998,
#   'Aecht Schlenkerla Kräusen': 999,
#   ...})

# %%
mapp=dataset.mapping()

# %%
beer=list(mapp[3])
raters=list(mapp[1])

# %%
(interactions, weight)= dataset.build_interactions([(x[5], x[0]) for x in df.values])

# %% [markdown]
# Created item and user feature to put in hybrid model

# %%
#make sure to put [] outside of second x to following the lightfm dataset rules
item_features = dataset.build_item_features([(x[0], [x[2]]) for x in df.values])
user_features = dataset.build_user_features([(x[5], [x[6]]) for x in df.values])

# %%
dataset.item_features_shape()
# Out:
# (4823, 4972)

# %%
#split train set, test set using lightfm library
train, test=random_train_test_split(interactions, test_percentage=.20, random_state=10)

# %%
print(repr(train))
print(repr(test))
# Out:
# <8121x4823 sparse matrix of type '<class 'numpy.int32'>'
# 	with 36284 stored elements in COOrdinate format>
# <8121x4823 sparse matrix of type '<class 'numpy.int32'>'
# 	with 9072 stored elements in COOrdinate format>

# %% [markdown]
# # Pure Collaborative Filtering model

# %%
pure_model=LightFM(loss='warp')

# %%
pure_model.fit(train,epochs=30, num_threads=2)

# %%
pure_model.predict(np.int32([1,90, 90]), np.int32([1,9, 67]))
# Out:
# array([ 1.0408082, -0.981616 , -4.34876  ], dtype=float32)

# %%
auc_score(pure_model, train).mean()
# Out:
# 0.9746668

# %%
auc_score(pure_model, test, train_interactions=train).mean()
# Out:
# 0.75442946

# %% [markdown]
# # Hybrid model

# %%
hybrid_model=LightFM(loss='warp')
hybrid_model.fit(train,user_features=user_features, item_features=item_features, epochs=30, num_threads=2)

# %%
auc_score(hybrid_model, train,user_features=user_features,item_features=item_features).mean()
# Out:
# 0.85724354

# %%
auc_score(hybrid_model, test, train_interactions=train,user_features=user_features, item_features=item_features).mean()
# Out:
# 0.7476198

# %% [markdown]
# Compared to Hybrid model, Pure Collaborative Filterring model performed better on both train set and test set. Therefore, I decided to use Pure Collaborative Filtering model to predict beer for rater

# %%
user=90
items=np.int32([10,23,56,432, 78, 90,56,796,567])

# %%
hybrid_model.predict(user,items)
# Out:
# array([-1.7690974 , -2.3363786 ,  0.11954585, -2.2323089 , -1.401464  ,
#        -3.9831336 ,  0.11954585, -2.426235  , -0.8164188 ], dtype=float32)

# %%
predictions=hybrid_model.predict(user, items)

# %%
beer_rec_order=np.argsort(-predictions)
beer_rec_order
# Out:
# array([2, 6, 8, 4, 0, 3, 1, 7, 5])

# %% [markdown]
# # Prediction Funtion

# %%
def recomment(model, data, users_id):
    n_users, n_items = train.shape
    for user in users_id:
        rater=raters[user]
        df_rater=df[df['Rater']=='{}'.format(rater)].sort_values(by='Rating', ascending=False)
        top3beer=df_rater['Beers'].values[:3]
        print("    Name of rater: {} ".format(rater))
        print('    - Drank beers: ')
        for b in top3beer:
            print(b)
        print('\n')
        print("   - Top 3 recommend beers for {} : ".format(rater))
        score=model.predict(user, np.arange(n_items))
        sortbeer=np.argsort(score)
        rate_beer=list(zip(sortbeer, np.arange(n_items)))
        for rating in rate_beer:
            if rating[0] < 3:
                bia=rating[1]
                print(beer[bia])
            else:
                pass
        print('\n')
        print('\n')

# %%
recomment(pure_model, train, [0,1,2])
# Out:
#     Name of rater: DCH
#     - Drank beers:
# Shipping Out of Boston
# Pilsener
# Pinstripe Pils
#
#
#    - Top 3 recommend beers for DCH :
# Carnivora
# Shift Happens No. 02 DDH Lager
# Where Is Your God Now?!
#
#
#
#
#     Name of rater: RobertB412
#     - Drank beers:
# Dunkel Lager
# Traditional Lager
# Oktoberfest
#
#
#    - Top 3 recommend beers for RobertB412 :
# The Premium Malt's
# Death By Powerpoint
# Where Is Your God Now?!
#
#
#
#
#     Name of rater: BarfyMan362
#     - Drank beers:
# Traditional Lager
#
#
#    - Top 3 recommend beers for BarfyMan362 :
# Hallertauer Hopfen-Cuvee
# Day Wrecker
# Where Is Your God Now?! (Teal Version)
